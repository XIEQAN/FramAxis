# %%
import pandas as pd
import numpy as np
from gensim.models import KeyedVectors
import os
from tqdm import tqdm
import time

# %%
# 设置文件路径
word2vec_model_path = 'D:\pythonProject\C_MFD2.0_embedding\词嵌入模型文件夹\zhihu\sgns.zhihu.word'
gst_excel_path = r'D:\pythonProject\C_MFD2.0_embedding\代码区域\FramAxis嵌入测试\指涉术语测试数据\测试GNT.xlsx'
output_csv_path = 'gnt_embeddings.csv'
print(f"开始执行GNT词向量嵌入任务...")
start_time = time.time()
# Out:
# 开始执行GNT词向量嵌入任务...

# %%
# 加载词向量模型
print(f"正在加载词向量模型: {word2vec_model_path}...")
try:
    word_vectors = KeyedVectors.load_word2vec_format(word2vec_model_path, binary=False)
    print(f"词向量模型加载成功，词汇量: {len(word_vectors.key_to_index)}")
except Exception as e:
    print(f"加载词向量模型时出错: {e}")
    raise
# Out:
# 正在加载词向量模型: D:\pythonProject\C_MFD2.0_embedding\词嵌入模型文件夹\zhihu\sgns.zhihu.word...
# 词向量模型加载成功，词汇量: 259869

# %%
# 加载GST词汇表
print(f"正在加载GNT词汇表: {os.path.basename(gst_excel_path)}...")
try:
    gst_df = pd.read_excel(gst_excel_path)
    # 确保DataFrame有正确的列名
    if len(gst_df.columns) >= 2:
        gst_df = gst_df.iloc[:, :2]  # 只选择前两列
        gst_df.columns = ['词语', '频率']  # 设置列名
    print(f"GNT词汇表加载成功，共{len(gst_df)}个词语")
except Exception as e:
    print(f"加载GNT词汇表时出错: {e}")
    raise
# Out:
# 正在加载GNT词汇表: 测试GNT.xlsx...
# GNT词汇表加载成功，共8261个词语

# %%
# 初始化结果DataFrame
results = []
missing_words = []

# 词向量维度
vector_dim = word_vectors.vector_size
print(f"词向量维度: {vector_dim}")

# 处理每个词语
print("开始处理词语...")
for _, row in tqdm(gst_df.iterrows(), total=len(gst_df), desc="处理进度"):
    word = row['词语']
    frequency = row['频率']

    try:
        # 检查词语是否在词向量模型中
        if word in word_vectors:
            # 获取词向量
            vector = word_vectors[word]

            # 准备一行数据
            result_row = {'词语': word, '频率': frequency}

            # 添加词向量维度
            for i in range(vector_dim):
                result_row[f'dim_{i + 1}'] = vector[i]

            results.append(result_row)
        else:
            missing_words.append(word)
            print(f"警告: 词语 '{word}' 不在词向量模型中")
    except Exception as e:
        print(f"处理词语 '{word}' 时出错: {e}")
        missing_words.append(word)

# 创建结果DataFrame
result_df = pd.DataFrame(results)

# 保存结果到CSV
print(f"正在保存结果到: {output_csv_path}...")
try:
    result_df.to_csv(output_csv_path, index=False, encoding='utf-8')
    print(f"结果已成功保存到: {output_csv_path}")
except Exception as e:
    print(f"保存结果时出错: {e}")

# 报告结果
print(f"\n处理完成:")
print(f"- 总词语数: {len(gst_df)}")
print(f"- 成功嵌入词语数: {len(results)}")
print(f"- 缺失词语数: {len(missing_words)}")

# 输出缺失词列表
if missing_words:
    print("\n缺失词列表:")
    for word in missing_words:
        print(f"- {word}")

end_time = time.time()
print(f"\n任务完成，耗时: {end_time - start_time:.2f}秒")
# Out:
# 词向量维度: 300
# 开始处理词语...
# 处理进度:  10%|▉         | 817/8261 [00:00<00:00, 8128.01it/s]
# 警告: 词语 '施暴者' 不在词向量模型中
# 警告: 词语 '答主' 不在词向量模型中
# 警告: 词语 '唐山人' 不在词向量模型中
# 警告: 词语 '评论区' 不在词向量模型中
# 警告: 词语 '孙小果' 不在词向量模型中
# 警告: 词语 '键盘侠' 不在词向量模型中
# 警告: 词语 '自媒体' 不在词向量模型中
# 警告: 词语 '扫黑除恶' 不在词向量模型中
# 警告: 词语 '街斗' 不在词向量模型中
# 警告: 词语 '红码' 不在词向量模型中
# 警告: 词语 '网友们' 不在词向量模型中
# 警告: 词语 '死手' 不在词向量模型中
# 警告: 词语 '理中客' 不在词向量模型中
# 警告: 词语 '垃圾人' 不在词向量模型中
# 警告: 词语 '层主' 不在词向量模型中
# 警告: 词语 '美帝' 不在词向量模型中
# 警告: 词语 '地图炮' 不在词向量模型中
# 警告: 词语 '战狼' 不在词向量模型中
# 警告: 词语 '点赞' 不在词向量模型中
# 警告: 词语 '网爆' 不在词向量模型中
# 警告: 词语 '嘴巴子' 不在词向量模型中
# 警告: 词语 '行凶者' 不在词向量模型中
# 警告: 词语 '社会人' 不在词向量模型中
# 警告: 词语 '法学生' 不在词向量模型中
# 警告: 词语 '黑涩会' 不在词向量模型中
# 警告: 词语 '六子' 不在词向量模型中
# 警告: 词语 '存在感' 不在词向量模型中
# 警告: 词语 '汤兰兰' 不在词向量模型中
# 警告: 词语 '题主' 不在词向量模型中
# 警告: 词语 '嘴炮' 不在词向量模型中
# 警告: 词语 '刘中伟' 不在词向量模型中
# 警告: 词语 '屁民' 不在词向量模型中
# 警告: 词语 '网红' 不在词向量模型中
# 警告: 词语 '烂人' 不在词向量模型中
# 警告: 词语 '张文平' 不在词向量模型中
# 警告: 词语 '打人案' 不在词向量模型中
# 警告: 词语 '菜刀队' 不在词向量模型中
# 警告: 词语 '网暴者' 不在词向量模型中
# 警告: 词语 '广众' 不在词向量模型中
# 警告: 词语 '施害者' 不在词向量模型中
# 警告: 词语 '上海人' 不在词向量模型中
# 警告: 词语 '格斗家' 不在词向量模型中
# 警告: 词语 '口嗨' 不在词向量模型中
# 警告: 词语 '怂包' 不在词向量模型中
# 警告: 词语 '骚扰者' 不在词向量模型中
# 警告: 词语 '营销号' 不在词向量模型中
# 警告: 词语 '法律人' 不在词向量模型中
# 警告: 词语 '狠人' 不在词向量模型中
# 警告: 词语 '尿性' 不在词向量模型中
# 警告: 词语 '施暴方' 不在词向量模型中
# 警告: 词语 '网军' 不在词向量模型中
# 警告: 词语 '键盘侠们' 不在词向量模型中
# 警告: 词语 '一伙' 不在词向量模型中
# 警告: 词语 '罗神贵' 不在词向量模型中
# 警告: 词语 '酒蒙子' 不在词向量模型中
# 警告: 词语 '灰衣' 不在词向量模型中
# 警告: 词语 '领导们' 不在词向量模型中
# 警告: 词语 '辣鸡' 不在词向量模型中
# 警告: 词语 '恨国党' 不在词向量模型中
# 警告: 词语 '打工人' 不在词向量模型中
# 警告: 词语 '全国人' 不在词向量模型中
# 警告: 词语 '黑伞' 不在词向量模型中
# 警告: 词语 '刘华强' 不在词向量模型中
# 警告: 词语 '小混混' 不在词向量模型中
# 警告: 词语 '广东人' 不在词向量模型中
# 警告: 词语 '还手之力' 不在词向量模型中
# 警告: 词语 '混混们' 不在词向量模型中
# 警告: 词语 '扫黑办' 不在词向量模型中
# 警告: 词语 '刘文玺' 不在词向量模型中
# 警告: 词语 '左淑娴' 不在词向量模型中
# 警告: 词语 '外媒' 不在词向量模型中
# 警告: 词语 '公众号' 不在词向量模型中
# 警告: 词语 '热评' 不在词向量模型中
# 警告: 词语 '暴恐' 不在词向量模型中
# 警告: 词语 '怂货' 不在词向量模型中
# 警告: 词语 '马云齐' 不在词向量模型中
# 警告: 词语 '张进平' 不在词向量模型中
# 警告: 词语 '小编' 不在词向量模型中
# 警告: 词语 '流氓们' 不在词向量模型中
# 警告: 词语 '砍人' 不在词向量模型中
# 警告: 词语 '施暴人' 不在词向量模型中
# 警告: 词语 '网评员' 不在词向量模型中
# 警告: 词语 '背锅' 不在词向量模型中
# 警告: 词语 '杠精' 不在词向量模型中
# 警告: 词语 '香港人' 不在词向量模型中
# 警告: 词语 '兵击' 不在词向量模型中
# 警告: 词语 '四手' 不在词向量模型中
# 警告: 词语 '家人们' 不在词向量模型中
# 警告: 词语 '文明城' 不在词向量模型中
# 警告: 词语 '张绳庆' 不在词向量模型中
# 警告: 词语 '郝秀林' 不在词向量模型中
# 警告: 词语 '网曝' 不在词向量模型中
# 警告: 词语 '三无小号' 不在词向量模型中
# 警告: 词语 '社畜' 不在词向量模型中
# 警告: 词语 '副局' 不在词向量模型中
# 警告: 词语 '黑警' 不在词向量模型中
# 警告: 词语 '花臂' 不在词向量模型中
# 警告: 词语 '屁孩' 不在词向量模型中
# 警告: 词语 '侵害者' 不在词向量模型中
# 警告: 词语 '宣传口' 不在词向量模型中
# 警告: 词语 '人设' 不在词向量模型中
# 警告: 词语 '网民们' 不在词向量模型中
# 警告: 词语 '明星们' 不在词向量模型中
# 警告: 词语 '报警者' 不在词向量模型中
# 警告: 词语 '饭圈' 不在词向量模型中
# 警告: 词语 '魔怔人' 不在词向量模型中
# 警告: 词语 '大侄子' 不在词向量模型中
# 警告: 词语 '张艳军' 不在词向量模型中
# 警告: 词语 '弱鸡' 不在词向量模型中
# 警告: 词语 '小瘪三' 不在词向量模型中
# 警告: 词语 '福建人' 不在词向量模型中
# 警告: 词语 '杨国全' 不在词向量模型中
# 警告: 词语 '张媛' 不在词向量模型中
# 警告: 词语 '不平等' 不在词向量模型中
# 警告: 词语 '许可馨' 不在词向量模型中
# 警告: 词语 '派警' 不在词向量模型中
# 警告: 词语 '前手' 不在词向量模型中
# 警告: 词语 '网信办' 不在词向量模型中
# 警告: 词语 '一己之力' 不在词向量模型中
# 警告: 词语 '尸位' 不在词向量模型中
# 警告: 词语 '看客们' 不在词向量模型中
# 警告: 词语 '利己主义者' 不在词向量模型中
# 警告: 词语 '格斗界' 不在词向量模型中
# 警告: 词语 '塔寨' 不在词向量模型中
# 警告: 词语 '发小' 不在词向量模型中
# 警告: 词语 '硬钢' 不在词向量模型中
# 警告: 词语 '董筱涵' 不在词向量模型中
# 警告: 词语 '高衙' 不在词向量模型中
# 警告: 词语 '体育生' 不在词向量模型中
# 警告: 词语 '最高法' 不在词向量模型中
# 警告: 词语 '徐敏' 不在词向量模型中
# 警告: 词语 '刘涌' 不在词向量模型中
# 警告: 词语 '社死' 不在词向量模型中
# 警告: 词语 '老师们' 不在词向量模型中
# 警告: 词语 '肥宅' 不在词向量模型中
# 警告: 词语 '陈晓亮' 不在词向量模型中
# 警告: 词语 '帮助犯' 不在词向量模型中
# 警告: 词语 '八竿子' 不在词向量模型中
# 警告: 词语 '法考' 不在词向量模型中
# 处理进度:  46%|████▋     | 3827/8261 [00:00<00:00, 9965.16it/s]
# 警告: 词语 '带路党' 不在词向量模型中
# 警告: 词语 '鱼霸' 不在词向量模型中
# 警告: 词语 '达利特' 不在词向量模型中
# 警告: 词语 '打黑除恶' 不在词向量模型中
# 警告: 词语 '小年轻' 不在词向量模型中
# 警告: 词语 '虞关荣' 不在词向量模型中
# 警告: 词语 '事业编' 不在词向量模型中
# 警告: 词语 '密接' 不在词向量模型中
# 警告: 词语 '大稽' 不在词向量模型中
# 警告: 词语 '白衣背' 不在词向量模型中
# 警告: 词语 '廊坊人' 不在词向量模型中
# 警告: 词语 '北工' 不在词向量模型中
# 警告: 词语 '二侄子' 不在词向量模型中
# 警告: 词语 '抖机灵' 不在词向量模型中
# 警告: 词语 '九漏鱼' 不在词向量模型中
# 警告: 词语 '祖国人' 不在词向量模型中
# 警告: 词语 '非杠' 不在词向量模型中
# 警告: 词语 '逗比' 不在词向量模型中
# 警告: 词语 '基本盘' 不在词向量模型中
# 警告: 词语 '乐子人' 不在词向量模型中
# 警告: 词语 '张麻子' 不在词向量模型中
# 警告: 词语 '半佛' 不在词向量模型中
# 警告: 词语 '背锅侠' 不在词向量模型中
# 警告: 词语 '老板们' 不在词向量模型中
# 警告: 词语 '群狼' 不在词向量模型中
# 警告: 词语 '巡查组' 不在词向量模型中
# 警告: 词语 '弱势者' 不在词向量模型中
# 警告: 词语 '菜刀帮' 不在词向量模型中
# 警告: 词语 '杨树宽' 不在词向量模型中
# 警告: 词语 '高明远' 不在词向量模型中
# 警告: 词语 '之士' 不在词向量模型中
# 警告: 词语 '戏子们' 不在词向量模型中
# 警告: 词语 '受害者们' 不在词向量模型中
# 警告: 词语 '冤种' 不在词向量模型中
# 警告: 词语 '二货' 不在词向量模型中
# 警告: 词语 '沙人' 不在词向量模型中
# 警告: 词语 '和事' 不在词向量模型中
# 警告: 词语 '弱势方' 不在词向量模型中
# 警告: 词语 '摇人' 不在词向量模型中
# 警告: 词语 '盐贩' 不在词向量模型中
# 警告: 词语 '对线' 不在词向量模型中
# 警告: 词语 '拳师们' 不在词向量模型中
# 警告: 词语 '普信' 不在词向量模型中
# 警告: 词语 '泰州人' 不在词向量模型中
# 警告: 词语 '黑社會' 不在词向量模型中
# 警告: 词语 '小混子' 不在词向量模型中
# 警告: 词语 '人者' 不在词向量模型中
# 警告: 词语 '顶流' 不在词向量模型中
# 警告: 词语 '孤勇者' 不在词向量模型中
# 警告: 词语 '富人区' 不在词向量模型中
# 警告: 词语 '白衣人' 不在词向量模型中
# 警告: 词语 '崔伟' 不在词向量模型中
# 警告: 词语 '课代表' 不在词向量模型中
# 警告: 词语 '群演' 不在词向量模型中
# 警告: 词语 '网曝者' 不在词向量模型中
# 警告: 词语 '弱小者' 不在词向量模型中
# 警告: 词语 '远某' 不在词向量模型中
# 警告: 词语 '伤人者' 不在词向量模型中
# 警告: 词语 '职业哥' 不在词向量模型中
# 警告: 词语 '砖家' 不在词向量模型中
# 警告: 词语 '张春平' 不在词向量模型中
# 警告: 词语 '理中客们' 不在词向量模型中
# 警告: 词语 '恶心人' 不在词向量模型中
# 警告: 词语 '骚操作' 不在词向量模型中
# 警告: 词语 '吴某凡' 不在词向量模型中
# 警告: 词语 '发声者' 不在词向量模型中
# 警告: 词语 '认怂' 不在词向量模型中
# 警告: 词语 '灭霸' 不在词向量模型中
# 警告: 词语 '陈礼' 不在词向量模型中
# 警告: 词语 '副部' 不在词向量模型中
# 警告: 词语 '谷某' 不在词向量模型中
# 警告: 词语 '恰饭' 不在词向量模型中
# 警告: 词语 '被害妄想症' 不在词向量模型中
# 警告: 词语 '大二' 不在词向量模型中
# 警告: 词语 '踏马' 不在词向量模型中
# 警告: 词语 '亲者' 不在词向量模型中
# 警告: 词语 '混子们' 不在词向量模型中
# 警告: 词语 '大三' 不在词向量模型中
# 警告: 词语 '身边人' 不在词向量模型中
# 警告: 词语 '喷子们' 不在词向量模型中
# 警告: 词语 '少斌' 不在词向量模型中
# 警告: 词语 '理性人' 不在词向量模型中
# 警告: 词语 '大四' 不在词向量模型中
# 警告: 词语 '秦皇岛人' 不在词向量模型中
# 警告: 词语 '株连九' 不在词向量模型中
# 警告: 词语 '入刑' 不在词向量模型中
# 警告: 词语 '短兵' 不在词向量模型中
# 警告: 词语 '武英级' 不在词向量模型中
# 警告: 词语 '狠手' 不在词向量模型中
# 警告: 词语 '家属们' 不在词向量模型中
# 警告: 词语 '怯者' 不在词向量模型中
# 警告: 词语 '罪犯们' 不在词向量模型中
# 警告: 词语 '讨论群' 不在词向量模型中
# 警告: 词语 '黄淑芬' 不在词向量模型中
# 警告: 词语 '官匪' 不在词向量模型中
# 警告: 词语 '云拳迷' 不在词向量模型中
# 警告: 词语 '韩兴博' 不在词向量模型中
# 警告: 词语 '救助人' 不在词向量模型中
# 警告: 词语 '霸凌者' 不在词向量模型中
# 警告: 词语 '陈雷' 不在词向量模型中
# 警告: 词语 '人籍' 不在词向量模型中
# 警告: 词语 '鉴伤' 不在词向量模型中
# 警告: 词语 '立场论者' 不在词向量模型中
# 警告: 词语 '阴谋论者' 不在词向量模型中
# 警告: 词语 '赖赖' 不在词向量模型中
# 警告: 词语 '杀童' 不在词向量模型中
# 警告: 词语 '鹰酱' 不在词向量模型中
# 警告: 词语 '背刺' 不在词向量模型中
# 警告: 词语 '失信人' 不在词向量模型中
# 警告: 词语 '大咖' 不在词向量模型中
# 警告: 词语 '小黄人' 不在词向量模型中
# 警告: 词语 '关注者' 不在词向量模型中
# 警告: 词语 '加害方' 不在词向量模型中
# 警告: 词语 '劝离' 不在词向量模型中
# 警告: 词语 '拳击界' 不在词向量模型中
# 警告: 词语 '郑屠' 不在词向量模型中
# 警告: 词语 '同事们' 不在词向量模型中
# 警告: 词语 '王菊' 不在词向量模型中
# 警告: 词语 '伟光' 不在词向量模型中
# 警告: 词语 '友友们' 不在词向量模型中
# 警告: 词语 '律人' 不在词向量模型中
# 警告: 词语 '废青' 不在词向量模型中
# 警告: 词语 '信服力' 不在词向量模型中
# 警告: 词语 '喷人' 不在词向量模型中
# 警告: 词语 '十三妹' 不在词向量模型中
# 警告: 词语 '爱豆' 不在词向量模型中
# 警告: 词语 '不负责' 不在词向量模型中
# 警告: 词语 '教资' 不在词向量模型中
# 警告: 词语 '小百姓' 不在词向量模型中
# 警告: 词语 '污人' 不在词向量模型中
# 警告: 词语 '吃瓜' 不在词向量模型中
# 警告: 词语 '流官' 不在词向量模型中
# 警告: 词语 '对战' 不在词向量模型中
# 警告: 词语 '恶警' 不在词向量模型中
# 警告: 词语 '鞋教' 不在词向量模型中
# 警告: 词语 '徒弟们' 不在词向量模型中
# 警告: 词语 '导员' 不在词向量模型中
# 警告: 词语 '打人方' 不在词向量模型中
# 警告: 词语 '工具人' 不在词向量模型中
# 警告: 词语 '暴徒们' 不在词向量模型中
# 警告: 词语 '带路者' 不在词向量模型中
# 警告: 词语 '劳东燕' 不在词向量模型中
# 警告: 词语 '见义勇' 不在词向量模型中
# 警告: 词语 '政军' 不在词向量模型中
# 警告: 词语 '身正' 不在词向量模型中
# 警告: 词语 '渔霸' 不在词向量模型中
# 警告: 词语 '小鱼小虾' 不在词向量模型中
# 警告: 词语 '喽喽' 不在词向量模型中
# 警告: 词语 '鸟样' 不在词向量模型中
# 警告: 词语 '打黑办' 不在词向量模型中
# 警告: 词语 '盲生' 不在词向量模型中
# 警告: 词语 '八蛋' 不在词向量模型中
# 警告: 词语 '三道杠' 不在词向量模型中
# 警告: 词语 '酒疯子' 不在词向量模型中
# 警告: 词语 '资本家们' 不在词向量模型中
# 警告: 词语 '马某齐' 不在词向量模型中
# 警告: 词语 '人神' 不在词向量模型中
# 警告: 词语 '黑社会们' 不在词向量模型中
# 警告: 词语 '民科' 不在词向量模型中
# 警告: 词语 '讲茶' 不在词向量模型中
# 警告: 词语 '他人之慨' 不在词向量模型中
# 警告: 词语 '张扣扣' 不在词向量模型中
# 警告: 词语 '兵王' 不在词向量模型中
# 警告: 词语 '八孩' 不在词向量模型中
# 警告: 词语 '欺凌者' 不在词向量模型中
# 警告: 词语 '暴恐黑' 不在词向量模型中
# 警告: 词语 '泱仕' 不在词向量模型中
# 警告: 词语 '鲍毓明' 不在词向量模型中
# 警告: 词语 '韦某木' 不在词向量模型中
# 警告: 词语 '博人' 不在词向量模型中
# 警告: 词语 '暴力团' 不在词向量模型中
# 警告: 词语 '警人' 不在词向量模型中
# 警告: 词语 '二代们' 不在词向量模型中
# 警告: 词语 '米尔扎耶夫' 不在词向量模型中
# 警告: 词语 '乔立夫' 不在词向量模型中
# 警告: 词语 '二傻子' 不在词向量模型中
# 警告: 词语 '傻缺' 不在词向量模型中
# 警告: 词语 '麻瓜' 不在词向量模型中
# 警告: 词语 '顾某' 不在词向量模型中
# 警告: 词语 '沈奕斐' 不在词向量模型中
# 警告: 词语 '脑勺' 不在词向量模型中
# 警告: 词语 '玉田人' 不在词向量模型中
# 警告: 词语 '警组' 不在词向量模型中
# 警告: 词语 '施害方' 不在词向量模型中
# 警告: 词语 '爆料人' 不在词向量模型中
# 警告: 词语 '致害人' 不在词向量模型中
# 警告: 词语 '造谣人' 不在词向量模型中
# 警告: 词语 '恨国' 不在词向量模型中
# 警告: 词语 '拳塔' 不在词向量模型中
# 警告: 词语 '学生们' 不在词向量模型中
# 警告: 词语 '正义侠' 不在词向量模型中
# 警告: 词语 '德棍' 不在词向量模型中
# 警告: 词语 '黑胖子' 不在词向量模型中
# 警告: 词语 '阿米尔卡汉' 不在词向量模型中
# 警告: 词语 '长兵' 不在词向量模型中
# 警告: 词语 '疾控' 不在词向量模型中
# 警告: 词语 '公安口' 不在词向量模型中
# 警告: 词语 '巡防队' 不在词向量模型中
# 警告: 词语 '葫芦僧' 不在词向量模型中
# 警告: 词语 '塔西佗' 不在词向量模型中
# 警告: 词语 '毁人' 不在词向量模型中
# 警告: 词语 '官黑' 不在词向量模型中
# 警告: 词语 '惨样' 不在词向量模型中
# 警告: 词语 '高华们' 不在词向量模型中
# 警告: 词语 '大棋党' 不在词向量模型中
# 警告: 词语 '半残' 不在词向量模型中
# 警告: 词语 '二民' 不在词向量模型中
# 警告: 词语 '上位者' 不在词向量模型中
# 警告: 词语 '熊心豹子' 不在词向量模型中
# 警告: 词语 '屁民们' 不在词向量模型中
# 警告: 词语 '专家们' 不在词向量模型中
# 警告: 词语 '劝架者' 不在词向量模型中
# 警告: 词语 '贝吉塔' 不在词向量模型中
# 警告: 词语 '白罩衫' 不在词向量模型中
# 警告: 词语 '人上人' 不在词向量模型中
# 警告: 词语 '鸡贼' 不在词向量模型中
# 警告: 词语 '为俊杰' 不在词向量模型中
# 警告: 词语 '脑残粉' 不在词向量模型中
# 警告: 词语 '人下' 不在词向量模型中
# 警告: 词语 '米锅' 不在词向量模型中
# 警告: 词语 '安东尼梅森' 不在词向量模型中
# 警告: 词语 '高半级' 不在词向量模型中
# 警告: 词语 '新闻人' 不在词向量模型中
# 警告: 词语 '起色心' 不在词向量模型中
# 警告: 词语 '数罪' 不在词向量模型中
# 警告: 词语 '正股级' 不在词向量模型中
# 警告: 词语 '精差' 不在词向量模型中
# 警告: 词语 '安徽人' 不在词向量模型中
# 警告: 词语 '大人们' 不在词向量模型中
# 警告: 词语 '删评' 不在词向量模型中
# 警告: 词语 '菜鸡' 不在词向量模型中
# 警告: 词语 '崽种' 不在词向量模型中
# 警告: 词语 '卑鄙者' 不在词向量模型中
# 警告: 词语 '保護傘' 不在词向量模型中
# 警告: 词语 '百姓们' 不在词向量模型中
# 警告: 词语 '大家长' 不在词向量模型中
# 警告: 词语 '助人者' 不在词向量模型中
# 警告: 词语 '装逼' 不在词向量模型中
# 警告: 词语 '醉酒人' 不在词向量模型中
# 警告: 词语 '老大们' 不在词向量模型中
# 警告: 词语 '记者们' 不在词向量模型中
# 警告: 词语 '贱命' 不在词向量模型中
# 警告: 词语 '人势' 不在词向量模型中
# 警告: 词语 '瓮刑' 不在词向量模型中
# 警告: 词语 '落水女' 不在词向量模型中
# 警告: 词语 '报案者' 不在词向量模型中
# 警告: 词语 '作奸犯' 不在词向量模型中
# 警告: 词语 '可怜人' 不在词向量模型中
# 警告: 词语 '快递员' 不在词向量模型中
# 警告: 词语 '硬杠' 不在词向量模型中
# 警告: 词语 '曹健华' 不在词向量模型中
# 警告: 词语 '戏精' 不在词向量模型中
# 警告: 词语 '学渣' 不在词向量模型中
# 警告: 词语 '嫌事' 不在词向量模型中
# 警告: 词语 '奥利给' 不在词向量模型中
# 警告: 词语 '赵晋' 不在词向量模型中
# 警告: 词语 '美芳' 不在词向量模型中
# 警告: 词语 '日本兵' 不在词向量模型中
# 警告: 词语 '网爆者' 不在词向量模型中
# 警告: 词语 '头铁' 不在词向量模型中
# 警告: 词语 '狱友们' 不在词向量模型中
# 警告: 词语 '资瓷' 不在词向量模型中
# 警告: 词语 '道德帝' 不在词向量模型中
# 警告: 词语 '法学家们' 不在词向量模型中
# 警告: 词语 '名族' 不在词向量模型中
# 警告: 词语 '自媒体们' 不在词向量模型中
# 警告: 词语 '杭州人' 不在词向量模型中
# 警告: 词语 '治下' 不在词向量模型中
# 警告: 词语 '金链子们' 不在词向量模型中
# 警告: 词语 '侵犯者' 不在词向量模型中
# 警告: 词语 '没钱人' 不在词向量模型中
# 警告: 词语 '执言' 不在词向量模型中
# 警告: 词语 '白衣郎' 不在词向量模型中
# 警告: 词语 '题家' 不在词向量模型中
# 警告: 词语 '穷逼' 不在词向量模型中
# 警告: 词语 '老白姓' 不在词向量模型中
# 警告: 词语 '暴力者' 不在词向量模型中
# 警告: 词语 '接盘侠' 不在词向量模型中
# 警告: 词语 '老百姓们' 不在词向量模型中
# 警告: 词语 '杜特尔特' 不在词向量模型中
# 警告: 词语 '副驾' 不在词向量模型中
# 警告: 词语 '沈某俊' 不在词向量模型中
# 警告: 词语 '节奏带' 不在词向量模型中
# 警告: 词语 '犯罪史' 不在词向量模型中
# 警告: 词语 '追剧' 不在词向量模型中
# 警告: 词语 '商某' 不在词向量模型中
# 警告: 词语 '盆友' 不在词向量模型中
# 警告: 词语 '寻常人' 不在词向量模型中
# 警告: 词语 '结婚率' 不在词向量模型中
# 警告: 词语 '冠军们' 不在词向量模型中
# 警告: 词语 '文烈宏' 不在词向量模型中
# 警告: 词语 '涉黑案' 不在词向量模型中
# 警告: 词语 '先烈们' 不在词向量模型中
# 警告: 词语 '脏事' 不在词向量模型中
# 警告: 词语 '极端主义者' 不在词向量模型中
# 警告: 词语 '怂狗' 不在词向量模型中
# 警告: 词语 '废宅' 不在词向量模型中
# 警告: 词语 '和平者' 不在词向量模型中
# 警告: 词语 '防卫者' 不在词向量模型中
# 警告: 词语 '正义之士' 不在词向量模型中
# 警告: 词语 '刘维国' 不在词向量模型中
# 警告: 词语 '人案' 不在词向量模型中
# 警告: 词语 '弈客' 不在词向量模型中
# 警告: 词语 '周梅森' 不在词向量模型中
# 警告: 词语 '苏北人' 不在词向量模型中
# 警告: 词语 '立执' 不在词向量模型中
# 警告: 词语 '混帮派' 不在词向量模型中
# 警告: 词语 '前科犯' 不在词向量模型中
# 警告: 词语 '邪教分子' 不在词向量模型中
# 警告: 词语 '要害人' 不在词向量模型中
# 警告: 词语 '茬架' 不在词向量模型中
# 警告: 词语 '揭阳案' 不在词向量模型中
# 警告: 词语 '唐山籍' 不在词向量模型中
# 警告: 词语 '脑浆子' 不在词向量模型中
# 警告: 词语 '全能神' 不在词向量模型中
# 警告: 词语 '中下巴' 不在词向量模型中
# 警告: 词语 '格斗吹' 不在词向量模型中
# 警告: 词语 '同伙们' 不在词向量模型中
# 警告: 词语 '秒人' 不在词向量模型中
# 警告: 词语 '紫带' 不在词向量模型中
# 警告: 词语 '手贱' 不在词向量模型中
# 警告: 词语 '健将级' 不在词向量模型中
# 警告: 词语 '死里' 不在词向量模型中
# 警告: 词语 '胆儿' 不在词向量模型中
# 警告: 词语 '猥亵犯' 不在词向量模型中
# 警告: 词语 '吴天' 不在词向量模型中
# 警告: 词语 '群众们' 不在词向量模型中
# 警告: 词语 '省管' 不在词向量模型中
# 警告: 词语 '社牛' 不在词向量模型中
# 警告: 词语 '俄乌' 不在词向量模型中
# 警告: 词语 '傻叉' 不在词向量模型中
# 警告: 词语 '桑兰' 不在词向量模型中
# 警告: 词语 '明白装' 不在词向量模型中
# 警告: 词语 '三观正' 不在词向量模型中
# 警告: 词语 '贱畜' 不在词向量模型中
# 警告: 词语 '十户' 不在词向量模型中
# 警告: 词语 '追击手' 不在词向量模型中
# 警告: 词语 '陈鹤高' 不在词向量模型中
# 警告: 词语 '军警界' 不在词向量模型中
# 警告: 词语 '乔西里' 不在词向量模型中
# 警告: 词语 '学伴' 不在词向量模型中
# 警告: 词语 '苏某' 不在词向量模型中
# 警告: 词语 '王馨平' 不在词向量模型中
# 警告: 词语 '大佬们' 不在词向量模型中
# 警告: 词语 '许凯' 不在词向量模型中
# 警告: 词语 '拉架人' 不在词向量模型中
# 警告: 词语 '林荷琴' 不在词向量模型中
# 警告: 词语 '陈慧敏' 不在词向量模型中
# 警告: 词语 '艾文礼' 不在词向量模型中
# 警告: 词语 '剃刀党' 不在词向量模型中
# 警告: 词语 '叼盘' 不在词向量模型中
# 警告: 词语 '胖虎' 不在词向量模型中
# 警告: 词语 '人事儿' 不在词向量模型中
# 警告: 词语 '懵逼' 不在词向量模型中
# 警告: 词语 '人拳' 不在词向量模型中
# 警告: 词语 '所做所为' 不在词向量模型中
# 警告: 词语 '判头' 不在词向量模型中
# 警告: 词语 '精神头' 不在词向量模型中
# 警告: 词语 '蒋光头' 不在词向量模型中
# 警告: 词语 '黑恶分子' 不在词向量模型中
# 警告: 词语 '装逼犯' 不在词向量模型中
# 警告: 词语 '渎职者' 不在词向量模型中
# 警告: 词语 '键盘们' 不在词向量模型中
# 警告: 词语 '管方' 不在词向量模型中
# 警告: 词语 '渣子们' 不在词向量模型中
# 警告: 词语 '全网榜三' 不在词向量模型中
# 警告: 词语 '资乎' 不在词向量模型中
# 警告: 词语 '黑办' 不在词向量模型中
# 警告: 词语 '渣浪' 不在词向量模型中
# 警告: 词语 '歹徒们' 不在词向量模型中
# 警告: 词语 '二狗子' 不在词向量模型中
# 警告: 词语 '中管' 不在词向量模型中
# 警告: 词语 '叠码仔' 不在词向量模型中
# 警告: 词语 '逼格' 不在词向量模型中
# 警告: 词语 '警会' 不在词向量模型中
# 警告: 词语 '鲁智' 不在词向量模型中
# 警告: 词语 '指虎' 不在词向量模型中
# 警告: 词语 '张秋平' 不在词向量模型中
# 警告: 词语 '张来平' 不在词向量模型中
# 警告: 词语 '主角们' 不在词向量模型中
# 警告: 词语 '实在人' 不在词向量模型中
# 警告: 词语 '大花臂' 不在词向量模型中
# 警告: 词语 '慷他人' 不在词向量模型中
# 警告: 词语 '村斗' 不在词向量模型中
# 警告: 词语 '喷点' 不在词向量模型中
# 警告: 词语 '狼狈样' 不在词向量模型中
# 警告: 词语 '豪横' 不在词向量模型中
# 警告: 词语 '调戏者' 不在词向量模型中
# 警告: 词语 '爆肝' 不在词向量模型中
# 警告: 词语 '防守方' 不在词向量模型中
# 警告: 词语 '米国人' 不在词向量模型中
# 警告: 词语 '白领们' 不在词向量模型中
# 警告: 词语 '官衣' 不在词向量模型中
# 警告: 词语 '主犯们' 不在词向量模型中
# 警告: 词语 '诬告者' 不在词向量模型中
# 警告: 词语 '旭阳' 不在词向量模型中
# 警告: 词语 '政治群' 不在词向量模型中
# 警告: 词语 '仇杀队' 不在词向量模型中
# 警告: 词语 '接触者' 不在词向量模型中
# 警告: 词语 '小弟们' 不在词向量模型中
# 警告: 词语 '信信' 不在词向量模型中
# 警告: 词语 '北青' 不在词向量模型中
# 警告: 词语 '对立方' 不在词向量模型中
# 警告: 词语 '弹反' 不在词向量模型中
# 警告: 词语 '军火贩' 不在词向量模型中
# 警告: 词语 '苏南人' 不在词向量模型中
# 警告: 词语 '诽谤性' 不在词向量模型中
# 警告: 词语 '诬蔑性' 不在词向量模型中
# 警告: 词语 '恶根' 不在词向量模型中
# 警告: 词语 '民众们' 不在词向量模型中
# 警告: 词语 '旁桌' 不在词向量模型中
# 警告: 词语 '叫嚣者' 不在词向量模型中
# 警告: 词语 '格斗圈' 不在词向量模型中
# 警告: 词语 '快警' 不在词向量模型中
# 警告: 词语 '德拉霍亚' 不在词向量模型中
# 警告: 词语 '格斗吹们' 不在词向量模型中
# 警告: 词语 '塞翁' 不在词向量模型中
# 警告: 词语 '特巡警' 不在词向量模型中
# 警告: 词语 '媒体们' 不在词向量模型中
# 警告: 词语 '官员们' 不在词向量模型中
# 警告: 词语 '家暴者' 不在词向量模型中
# 警告: 词语 '精英们' 不在词向量模型中
# 警告: 词语 '窃钩者' 不在词向量模型中
# 警告: 词语 '释迦摩尼' 不在词向量模型中
# 警告: 词语 '刘学周' 不在词向量模型中
# 警告: 词语 '枪使' 不在词向量模型中
# 警告: 词语 '疯批' 不在词向量模型中
# 警告: 词语 '误导人' 不在词向量模型中
# 警告: 词语 '遗少' 不在词向量模型中
# 警告: 词语 '周边人' 不在词向量模型中
# 警告: 词语 '炸号' 不在词向量模型中
# 警告: 词语 '麻木旁观者' 不在词向量模型中
# 警告: 词语 '张小果' 不在词向量模型中
# 警告: 词语 '下水军' 不在词向量模型中
# 警告: 词语 '逆民' 不在词向量模型中
# 警告: 词语 '受伤害者' 不在词向量模型中
# 警告: 词语 '脑内' 不在词向量模型中
# 警告: 词语 '迈克贝' 不在词向量模型中
# 警告: 词语 '王德宾' 不在词向量模型中
# 警告: 词语 '人們' 不在词向量模型中
# 警告: 词语 '炮王' 不在词向量模型中
# 警告: 词语 '施恶者' 不在词向量模型中
# 警告: 词语 '韦兆安' 不在词向量模型中
# 警告: 词语 '白衣侠' 不在词向量模型中
# 警告: 词语 '金心金意' 不在词向量模型中
# 警告: 词语 '旁观人' 不在词向量模型中
# 警告: 词语 '戚秦' 不在词向量模型中
# 警告: 词语 '一份子' 不在词向量模型中
# 警告: 词语 '宣传者' 不在词向量模型中
# 警告: 词语 '华人们' 不在词向量模型中
# 警告: 词语 '升斗' 不在词向量模型中
# 警告: 词语 '企鹅人' 不在词向量模型中
# 警告: 词语 '店里人' 不在词向量模型中
# 警告: 词语 '二大爷' 不在词向量模型中
# 警告: 词语 '扫黑组' 不在词向量模型中
# 警告: 词语 '小卒子' 不在词向量模型中
# 警告: 词语 '趣缘' 不在词向量模型中
# 警告: 词语 '本土派' 不在词向量模型中
# 警告: 词语 '麻匪' 不在词向量模型中
# 警告: 词语 '饮酒人' 不在词向量模型中
# 警告: 词语 '被伤者' 不在词向量模型中
# 警告: 词语 '干部们' 不在词向量模型中
# 警告: 词语 '高海皇' 不在词向量模型中
# 警告: 词语 '施害人' 不在词向量模型中
# 警告: 词语 '大斌' 不在词向量模型中
# 警告: 词语 '三连' 不在词向量模型中
# 警告: 词语 '马勒戈壁' 不在词向量模型中
# 警告: 词语 '英雄们' 不在词向量模型中
# 警告: 词语 '抓人' 不在词向量模型中
# 警告: 词语 '战狼们' 不在词向量模型中
# 警告: 词语 '鳄鱼帮' 不在词向量模型中
# 警告: 词语 '教培' 不在词向量模型中
# 警告: 词语 '惑仔' 不在词向量模型中
# 警告: 词语 '不婚' 不在词向量模型中
# 警告: 词语 '江苏籍' 不在词向量模型中
# 警告: 词语 '人屁' 不在词向量模型中
# 警告: 词语 '边缘人' 不在词向量模型中
# 警告: 词语 '无关者' 不在词向量模型中
# 警告: 词语 '狗屁话' 不在词向量模型中
# 警告: 词语 '洗地党' 不在词向量模型中
# 警告: 词语 '暴力犯' 不在词向量模型中
# 警告: 词语 '参战方' 不在词向量模型中
# 警告: 词语 '肖三' 不在词向量模型中
# 警告: 词语 '代表们' 不在词向量模型中
# 警告: 词语 '红花会' 不在词向量模型中
# 警告: 词语 '衢州人' 不在词向量模型中
# 警告: 词语 '检察组' 不在词向量模型中
# 警告: 词语 '橘生' 不在词向量模型中
# 警告: 词语 '县霸' 不在词向量模型中
# 警告: 词语 '老铁们' 不在词向量模型中
# 警告: 词语 '砍人案' 不在词向量模型中
# 警告: 词语 '歪果仁' 不在词向量模型中
# 警告: 词语 '色情业' 不在词向量模型中
# 警告: 词语 '老家人' 不在词向量模型中
# 警告: 词语 '傻子们' 不在词向量模型中
# 警告: 词语 '倒地者' 不在词向量模型中
# 警告: 词语 '进局子' 不在词向量模型中
# 警告: 词语 '吃瓜群' 不在词向量模型中
# 警告: 词语 '渣滓们' 不在词向量模型中
# 警告: 词语 '娄娄' 不在词向量模型中
# 警告: 词语 '孙启龙' 不在词向量模型中
# 警告: 词语 '张春来' 不在词向量模型中
# 警告: 词语 '赤鸡' 不在词向量模型中
# 警告: 词语 '咖位' 不在词向量模型中
# 警告: 词语 '公仆们' 不在词向量模型中
# 警告: 词语 '刁民们' 不在词向量模型中
# 警告: 词语 '安那其' 不在词向量模型中
# 警告: 词语 '白衣胖子' 不在词向量模型中
# 警告: 词语 '一帮子' 不在词向量模型中
# 警告: 词语 '轮凳子' 不在词向量模型中
# 警告: 词语 '近墨者' 不在词向量模型中
# 警告: 词语 '正主' 不在词向量模型中
# 警告: 词语 '逃刑犯' 不在词向量模型中
# 警告: 词语 '爱国党' 不在词向量模型中
# 警告: 词语 '草民们' 不在词向量模型中
# 警告: 词语 '远程兵' 不在词向量模型中
# 警告: 词语 '泰国人' 不在词向量模型中
# 警告: 词语 '习武人' 不在词向量模型中
# 警告: 词语 '号主' 不在词向量模型中
# 警告: 词语 '巨婴们' 不在词向量模型中
# 警告: 词语 '大陆人' 不在词向量模型中
# 警告: 词语 '碰瓷者' 不在词向量模型中
# 警告: 词语 '点边' 不在词向量模型中
# 警告: 词语 '嚣张跋扈' 不在词向量模型中
# 警告: 词语 '亲子班' 不在词向量模型中
# 警告: 词语 '贪官们' 不在词向量模型中
# 警告: 词语 '公安厅长' 不在词向量模型中
# 警告: 词语 '嘿鹅' 不在词向量模型中
# 警告: 词语 '张棋标' 不在词向量模型中
# 警告: 词语 '张峰锋' 不在词向量模型中
# 警告: 词语 '小艳' 不在词向量模型中
# 警告: 词语 '张锋锋' 不在词向量模型中
# 警告: 词语 '灼见' 不在词向量模型中
# 警告: 词语 '警校生' 不在词向量模型中
# 警告: 词语 '圈粉' 不在词向量模型中
# 警告: 词语 '自嗨' 不在词向量模型中
# 警告: 词语 '体问' 不在词向量模型中
# 警告: 词语 '正局' 不在词向量模型中
# 警告: 词语 '施虐欲' 不在词向量模型中
# 警告: 词语 '强势者' 不在词向量模型中
# 警告: 词语 '黄帽' 不在词向量模型中
# 警告: 词语 '雅利安人' 不在词向量模型中
# 警告: 词语 '威肋' 不在词向量模型中
# 警告: 词语 '名道姓' 不在词向量模型中
# 警告: 词语 '共情者' 不在词向量模型中
# 警告: 词语 '傻屌' 不在词向量模型中
# 警告: 词语 '撕逼' 不在词向量模型中
# 警告: 词语 '嘴贱' 不在词向量模型中
# 警告: 词语 '老哥们' 不在词向量模型中
# 警告: 词语 '圣母心' 不在词向量模型中
# 警告: 词语 '粉丝们' 不在词向量模型中
# 警告: 词语 '以上们' 不在词向量模型中
# 警告: 词语 '周树人' 不在词向量模型中
# 警告: 词语 '涉恶' 不在词向量模型中
# 警告: 词语 '法官们' 不在词向量模型中
# 警告: 词语 '司马昭之' 不在词向量模型中
# 警告: 词语 '船霸' 不在词向量模型中
# 警告: 词语 '记者籍' 不在词向量模型中
# 警告: 词语 '娱记' 不在词向量模型中
# 警告: 词语 '鉴定师' 不在词向量模型中
# 警告: 词语 '肥头' 不在词向量模型中
# 警告: 词语 '药神' 不在词向量模型中
# 警告: 词语 '吹哨人' 不在词向量模型中
# 警告: 词语 '暑期工' 不在词向量模型中
# 警告: 词语 '泰森来' 不在词向量模型中
# 警告: 词语 '邪典' 不在词向量模型中
# 警告: 词语 '日天' 不在词向量模型中
# 警告: 词语 '酒晕子' 不在词向量模型中
# 警告: 词语 '狼兵' 不在词向量模型中
# 警告: 词语 '成都人' 不在词向量模型中
# 警告: 词语 '包庇者' 不在词向量模型中
# 警告: 词语 '犯罪份子' 不在词向量模型中
# 警告: 词语 '组织人' 不在词向量模型中
# 警告: 词语 '对桌' 不在词向量模型中
# 警告: 词语 '陈谋志' 不在词向量模型中
# 警告: 词语 '高尚者' 不在词向量模型中
# 警告: 词语 '能力人' 不在词向量模型中
# 警告: 词语 '键仙' 不在词向量模型中
# 警告: 词语 '余欢水' 不在词向量模型中
# 警告: 词语 '宋襄公' 不在词向量模型中
# 警告: 词语 '社达' 不在词向量模型中
# 警告: 词语 '农村人' 不在词向量模型中
# 警告: 词语 '受助人' 不在词向量模型中
# 警告: 词语 '流氓话' 不在词向量模型中
# 警告: 词语 '牛逼症' 不在词向量模型中
# 警告: 词语 '政府派' 不在词向量模型中
# 警告: 词语 '小毛孩' 不在词向量模型中
# 警告: 词语 '香蕉人' 不在词向量模型中
# 警告: 词语 '无脑人' 不在词向量模型中
# 警告: 词语 '先辈们' 不在词向量模型中
# 警告: 词语 '防衛' 不在词向量模型中
# 警告: 词语 '质疑者' 不在词向量模型中
# 警告: 词语 '绿衣男子' 不在词向量模型中
# 警告: 词语 '留言者' 不在词向量模型中
# 警告: 词语 '小喽喽' 不在词向量模型中
# 警告: 词语 '警擦' 不在词向量模型中
# 警告: 词语 '重手' 不在词向量模型中
# 警告: 词语 '怀疑主义者' 不在词向量模型中
# 警告: 词语 '杀童犯' 不在词向量模型中
# 警告: 词语 '姜小亮' 不在词向量模型中
# 警告: 词语 '泰吹' 不在词向量模型中
# 警告: 词语 '面包人' 不在词向量模型中
# 警告: 词语 '牢友' 不在词向量模型中
# 警告: 词语 '低人' 不在词向量模型中
# 警告: 词语 '出轨者' 不在词向量模型中
# 警告: 词语 '善良者' 不在词向量模型中
# 警告: 词语 '杂碎们' 不在词向量模型中
# 警告: 词语 '路匪' 不在词向量模型中
# 警告: 词语 '装外宾' 不在词向量模型中
# 警告: 词语 '罗冠军' 不在词向量模型中
# 警告: 词语 '阿里周某' 不在词向量模型中
# 警告: 词语 '當地人' 不在词向量模型中
# 警告: 词语 '反应人' 不在词向量模型中
# 警告: 词语 '大宋子民' 不在词向量模型中
# 警告: 词语 '黑拳' 不在词向量模型中
# 警告: 词语 '拳峰' 不在词向量模型中
# 警告: 词语 '理论派' 不在词向量模型中
# 警告: 词语 '陈某人' 不在词向量模型中
# 警告: 词语 '赛科维奇' 不在词向量模型中
# 警告: 词语 '兔友' 不在词向量模型中
# 警告: 词语 '安德拉德' 不在词向量模型中
# 警告: 词语 '谢帕德' 不在词向量模型中
# 警告: 词语 '拉苏' 不在词向量模型中
# 警告: 词语 '鲁提辖' 不在词向量模型中
# 警告: 词语 '教育人' 不在词向量模型中
# 警告: 词语 '小孩崽子' 不在词向量模型中
# 警告: 词语 '家长们' 不在词向量模型中
# 警告: 词语 '胡脸' 不在词向量模型中
# 警告: 词语 '郑州人' 不在词向量模型中
# 警告: 词语 '晨晟' 不在词向量模型中
# 警告: 词语 '兴化人' 不在词向量模型中
# 警告: 词语 '章西' 不在词向量模型中
# 警告: 词语 '浩南' 不在词向量模型中
# 警告: 词语 '搏击手' 不在词向量模型中
# 警告: 词语 '横纲' 不在词向量模型中
# 警告: 词语 '顾某杰' 不在词向量模型中
# 警告: 词语 '李赛高' 不在词向量模型中
# 警告: 词语 '格斗手' 不在词向量模型中
# 警告: 词语 '汉谟拉比' 不在词向量模型中
# 警告: 词语 '人社' 不在词向量模型中
# 警告: 词语 '老乡群' 不在词向量模型中
# 警告: 词语 '法助' 不在词向量模型中
# 警告: 词语 '乎友' 不在词向量模型中
# 警告: 词语 '无辜人' 不在词向量模型中
# 警告: 词语 '董耀' 不在词向量模型中
# 警告: 词语 '狗崽子们' 不在词向量模型中
# 警告: 词语 '刘彦平' 不在词向量模型中
# 警告: 词语 '海港区人' 不在词向量模型中
# 警告: 词语 '叶某某' 不在词向量模型中
# 警告: 词语 '嘴欠' 不在词向量模型中
# 警告: 词语 '侵害方' 不在词向量模型中
# 警告: 词语 '测试员' 不在词向量模型中
# 警告: 词语 '巡特警' 不在词向量模型中
# 警告: 词语 '马科长' 不在词向量模型中
# 警告: 词语 '土木人' 不在词向量模型中
# 警告: 词语 '答辩者' 不在词向量模型中
# 警告: 词语 '侏儒人' 不在词向量模型中
# 警告: 词语 '罗伊韦德' 不在词向量模型中
# 警告: 词语 '柱力' 不在词向量模型中
# 警告: 词语 '柱中人' 不在词向量模型中
# 警告: 词语 '颜某' 不在词向量模型中
# 警告: 词语 '少年头' 不在词向量模型中
# 警告: 词语 '保护伞们' 不在词向量模型中
# 警告: 词语 '阿中' 不在词向量模型中
# 警告: 词语 '王志鹏' 不在词向量模型中
# 警告: 词语 '美吹' 不在词向量模型中
# 警告: 词语 '刀妹的' 不在词向量模型中
# 警告: 词语 '西语系' 不在词向量模型中
# 警告: 词语 '俊臣' 不在词向量模型中
# 警告: 词语 '羁押期' 不在词向量模型中
# 警告: 词语 '腕豪' 不在词向量模型中
# 警告: 词语 '饭圈粉' 不在词向量模型中
# 警告: 词语 '俩口子' 不在词向量模型中
# 警告: 词语 '反黑组' 不在词向量模型中
# 警告: 词语 '广东仔' 不在词向量模型中
# 警告: 词语 '河南银' 不在词向量模型中
# 警告: 词语 '立场主义者' 不在词向量模型中
# 警告: 词语 '坏心思' 不在词向量模型中
# 警告: 词语 '滋事者' 不在词向量模型中
# 警告: 词语 '一行人' 不在词向量模型中
# 警告: 词语 '李成阳' 不在词向量模型中
# 处理进度:  77%|███████▋  | 6346/8261 [00:00<00:00, 11589.82it/s]
# 警告: 词语 '狼叔' 不在词向量模型中
# 警告: 词语 '焦彦龙' 不在词向量模型中
# 警告: 词语 '张古江' 不在词向量模型中
# 警告: 词语 '诸葛宇杰' 不在词向量模型中
# 警告: 词语 '霉蛋' 不在词向量模型中
# 警告: 词语 '米欧奇' 不在词向量模型中
# 警告: 词语 '行刑者' 不在词向量模型中
# 警告: 词语 '谣言者' 不在词向量模型中
# 警告: 词语 '网暴人' 不在词向量模型中
# 警告: 词语 '李闰' 不在词向量模型中
# 警告: 词语 '苏州人' 不在词向量模型中
# 警告: 词语 '阿贝阿塔' 不在词向量模型中
# 警告: 词语 '农民们' 不在词向量模型中
# 警告: 词语 '孙火旺' 不在词向量模型中
# 警告: 词语 '山东话' 不在词向量模型中
# 警告: 词语 '豆瓣人' 不在词向量模型中
# 警告: 词语 '畜渣' 不在词向量模型中
# 警告: 词语 '德子' 不在词向量模型中
# 警告: 词语 '徐州人' 不在词向量模型中
# 警告: 词语 '主从犯' 不在词向量模型中
# 警告: 词语 '钢铁人' 不在词向量模型中
# 警告: 词语 '车警' 不在词向量模型中
# 警告: 词语 '小白鞋' 不在词向量模型中
# 警告: 词语 '老炮儿' 不在词向量模型中
# 警告: 词语 '小混' 不在词向量模型中
# 警告: 词语 '助威者' 不在词向量模型中
# 警告: 词语 '裱糊匠' 不在词向量模型中
# 警告: 词语 '洪拳' 不在词向量模型中
# 警告: 词语 '闰芳' 不在词向量模型中
# 警告: 词语 '帖主' 不在词向量模型中
# 警告: 词语 '高翻' 不在词向量模型中
# 警告: 词语 '控屏' 不在词向量模型中
# 警告: 词语 '袁宝璟' 不在词向量模型中
# 警告: 词语 '圈苟' 不在词向量模型中
# 警告: 词语 '张开印' 不在词向量模型中
# 警告: 词语 '温某' 不在词向量模型中
# 警告: 词语 '夏之光' 不在词向量模型中
# 警告: 词语 '江浙人' 不在词向量模型中
# 警告: 词语 '周秉义' 不在词向量模型中
# 警告: 词语 '好官' 不在词向量模型中
# 警告: 词语 '匪警' 不在词向量模型中
# 警告: 词语 '洼地人' 不在词向量模型中
# 警告: 词语 '赵俊' 不在词向量模型中
# 警告: 词语 '高彦' 不在词向量模型中
# 警告: 词语 '东北大' 不在词向量模型中
# 警告: 词语 '控制欲' 不在词向量模型中
# 警告: 词语 '张冠李' 不在词向量模型中
# 警告: 词语 '公考编' 不在词向量模型中
# 警告: 词语 '监察组' 不在词向量模型中
# 警告: 词语 '侦查局' 不在词向量模型中
# 警告: 词语 '拉拉案' 不在词向量模型中
# 警告: 词语 '打赏' 不在词向量模型中
# 警告: 词语 '出轨率' 不在词向量模型中
# 警告: 词语 '模仿犯' 不在词向量模型中
# 警告: 词语 '逼事' 不在词向量模型中
# 警告: 词语 '右脸' 不在词向量模型中
# 警告: 词语 '網民' 不在词向量模型中
# 警告: 词语 '妙手医生' 不在词向量模型中
# 警告: 词语 '家族人' 不在词向量模型中
# 警告: 词语 '测量者' 不在词向量模型中
# 警告: 词语 '起家人' 不在词向量模型中
# 警告: 词语 '游侠式' 不在词向量模型中
# 警告: 词语 '斧头喷子' 不在词向量模型中
# 警告: 词语 '肩担道义' 不在词向量模型中
# 警告: 词语 '张欲乞' 不在词向量模型中
# 警告: 词语 '雨琦' 不在词向量模型中
# 警告: 词语 '衰样' 不在词向量模型中
# 警告: 词语 '乌合之' 不在词向量模型中
# 警告: 词语 '行业者' 不在词向量模型中
# 警告: 词语 '李心' 不在词向量模型中
# 警告: 词语 '博白人' 不在词向量模型中
# 警告: 词语 '邓公千古' 不在词向量模型中
# 警告: 词语 '黑官' 不在词向量模型中
# 警告: 词语 '空降派' 不在词向量模型中
# 警告: 词语 '带头者' 不在词向量模型中
# 警告: 词语 '暗器师' 不在词向量模型中
# 警告: 词语 '法外之人' 不在词向量模型中
# 警告: 词语 '格斗痴' 不在词向量模型中
# 警告: 词语 '工务员' 不在词向量模型中
# 警告: 词语 '不着调' 不在词向量模型中
# 警告: 词语 '弱着者' 不在词向量模型中
# 警告: 词语 '花人' 不在词向量模型中
# 警告: 词语 '警勤' 不在词向量模型中
# 警告: 词语 '对儿' 不在词向量模型中
# 警告: 词语 '迷之操作' 不在词向量模型中
# 警告: 词语 '唐探' 不在词向量模型中
# 警告: 词语 '府台' 不在词向量模型中
# 警告: 词语 '土豪分' 不在词向量模型中
# 警告: 词语 '贼王' 不在词向量模型中
# 警告: 词语 '爆料者' 不在词向量模型中
# 警告: 词语 '面包车人' 不在词向量模型中
# 警告: 词语 '脑残们' 不在词向量模型中
# 警告: 词语 '建政派' 不在词向量模型中
# 警告: 词语 '天杀' 不在词向量模型中
# 警告: 词语 '五鼠' 不在词向量模型中
# 警告: 词语 '小王八办' 不在词向量模型中
# 警告: 词语 '宵小鼠辈' 不在词向量模型中
# 警告: 词语 '义劲' 不在词向量模型中
# 警告: 词语 '劝酒者' 不在词向量模型中
# 警告: 词语 '土豪金' 不在词向量模型中
# 警告: 词语 '炮头' 不在词向量模型中
# 警告: 词语 '恶渣' 不在词向量模型中
# 警告: 词语 '坑货' 不在词向量模型中
# 警告: 词语 '张屠夫' 不在词向量模型中
# 警告: 词语 '胡屠夫' 不在词向量模型中
# 警告: 词语 '本地虎' 不在词向量模型中
# 警告: 词语 '挽尊文' 不在词向量模型中
# 警告: 词语 '护渣子' 不在词向量模型中
# 警告: 词语 '网络警' 不在词向量模型中
# 警告: 词语 '防卫人' 不在词向量模型中
# 警告: 词语 '人建勇为' 不在词向量模型中
# 警告: 词语 '医头' 不在词向量模型中
# 警告: 词语 '犯案人' 不在词向量模型中
# 警告: 词语 '老辈人' 不在词向量模型中
# 警告: 词语 '刘捕' 不在词向量模型中
# 警告: 词语 '冤死鬼' 不在词向量模型中
# 警告: 词语 '继父母' 不在词向量模型中
# 警告: 词语 '首恶者' 不在词向量模型中
# 警告: 词语 '个名星' 不在词向量模型中
# 警告: 词语 '明星圈' 不在词向量模型中
# 警告: 词语 '相关方' 不在词向量模型中
# 警告: 词语 '卫国者' 不在词向量模型中
# 警告: 词语 '神经人' 不在词向量模型中
# 警告: 词语 '造谣者们' 不在词向量模型中
# 警告: 词语 '同鞋们' 不在词向量模型中
# 警告: 词语 '主把' 不在词向量模型中
# 警告: 词语 '动杀心' 不在词向量模型中
# 警告: 词语 '萨婆阿他' 不在词向量模型中
# 警告: 词语 '狍子们' 不在词向量模型中
# 警告: 词语 '原画师' 不在词向量模型中
# 警告: 词语 '洗白军' 不在词向量模型中
# 警告: 词语 '黑心者' 不在词向量模型中
# 警告: 词语 '警察长' 不在词向量模型中
# 警告: 词语 '拉边上' 不在词向量模型中
# 警告: 词语 '权名' 不在词向量模型中
# 警告: 词语 '喷神' 不在词向量模型中
# 警告: 词语 '日光族' 不在词向量模型中
# 警告: 词语 '周光族' 不在词向量模型中
# 警告: 词语 '护刀者' 不在词向量模型中
# 警告: 词语 '猪盘' 不在词向量模型中
# 警告: 词语 '收门生' 不在词向量模型中
# 警告: 词语 '心花路放' 不在词向量模型中
# 警告: 词语 '狗乎' 不在词向量模型中
# 警告: 词语 '互助者' 不在词向量模型中
# 警告: 词语 '热闹者' 不在词向量模型中
# 警告: 词语 '施工者' 不在词向量模型中
# 警告: 词语 '正办' 不在词向量模型中
# 警告: 词语 '怪茬' 不在词向量模型中
# 警告: 词语 '屋内人' 不在词向量模型中
# 警告: 词语 '维京人' 不在词向量模型中
# 警告: 词语 '家属长' 不在词向量模型中
# 警告: 词语 '魔性笑' 不在词向量模型中
# 警告: 词语 '驻警' 不在词向量模型中
# 警告: 词语 '本泰迪' 不在词向量模型中
# 警告: 词语 '锅蝻' 不在词向量模型中
# 警告: 词语 '优势方' 不在词向量模型中
# 警告: 词语 '文忙' 不在词向量模型中
# 警告: 词语 '同桌人' 不在词向量模型中
# 警告: 词语 '三亲六故' 不在词向量模型中
# 警告: 词语 '观场' 不在词向量模型中
# 警告: 词语 '反击者' 不在词向量模型中
# 警告: 词语 '穷人们' 不在词向量模型中
# 警告: 词语 '子弟兵们' 不在词向量模型中
# 警告: 词语 '酒懵子' 不在词向量模型中
# 警告: 词语 '小红帽们' 不在词向量模型中
# 警告: 词语 '美媒' 不在词向量模型中
# 警告: 词语 '卡萨雷斯' 不在词向量模型中
# 警告: 词语 '新晋' 不在词向量模型中
# 警告: 词语 '胳膊腿' 不在词向量模型中
# 警告: 词语 '尔朱荣' 不在词向量模型中
# 警告: 词语 '葛六' 不在词向量模型中
# 警告: 词语 '葛力姆乔' 不在词向量模型中
# 警告: 词语 '道上江湖' 不在词向量模型中
# 警告: 词语 '踢馆人' 不在词向量模型中
# 警告: 词语 '泰老虎' 不在词向量模型中
# 警告: 词语 '刀法家' 不在词向量模型中
# 警告: 词语 '剑术家' 不在词向量模型中
# 警告: 词语 '荒天帝' 不在词向量模型中
# 警告: 词语 '司乘' 不在词向量模型中
# 警告: 词语 '吹子' 不在词向量模型中
# 警告: 词语 '养蚕人' 不在词向量模型中
# 警告: 词语 '瓜民' 不在词向量模型中
# 警告: 词语 '千万富翁' 不在词向量模型中
# 警告: 词语 '穷光' 不在词向量模型中
# 警告: 词语 '街斗王' 不在词向量模型中
# 警告: 词语 '对像' 不在词向量模型中
# 警告: 词语 '队手' 不在词向量模型中
# 警告: 词语 '通讯连' 不在词向量模型中
# 警告: 词语 '得者' 不在词向量模型中
# 警告: 词语 '鼠鼠人' 不在词向量模型中
# 警告: 词语 '危墙之下' 不在词向量模型中
# 警告: 词语 '大佛们' 不在词向量模型中
# 警告: 词语 '庄里人' 不在词向量模型中
# 警告: 词语 '主脚' 不在词向量模型中
# 警告: 词语 '当局长' 不在词向量模型中
# 警告: 词语 '市调人' 不在词向量模型中
# 警告: 词语 '清北人' 不在词向量模型中
# 警告: 词语 '富官二代' 不在词向量模型中
# 警告: 词语 '无脑者' 不在词向量模型中
# 警告: 词语 '润党' 不在词向量模型中
# 警告: 词语 '路政支' 不在词向量模型中
# 警告: 词语 '废青们' 不在词向量模型中
# 警告: 词语 '按察' 不在词向量模型中
# 警告: 词语 '协辅警' 不在词向量模型中
# 警告: 词语 '监狱网评员' 不在词向量模型中
# 警告: 词语 '律协' 不在词向量模型中
# 警告: 词语 '本硕医' 不在词向量模型中
# 警告: 词语 '小到达' 不在词向量模型中
# 警告: 词语 '大巴掌' 不在词向量模型中
# 警告: 词语 '良心粉' 不在词向量模型中
# 警告: 词语 '巨佬' 不在词向量模型中
# 警告: 词语 '权人' 不在词向量模型中
# 警告: 词语 '洗脑包' 不在词向量模型中
# 警告: 词语 '恶霸们' 不在词向量模型中
# 警告: 词语 '百京人' 不在词向量模型中
# 警告: 词语 '宫里人' 不在词向量模型中
# 警告: 词语 '后头客' 不在词向量模型中
# 警告: 词语 '审判团' 不在词向量模型中
# 警告: 词语 '害群之蚂' 不在词向量模型中
# 警告: 词语 '噩魔' 不在词向量模型中
# 警告: 词语 '健人' 不在词向量模型中
# 警告: 词语 '人在' 不在词向量模型中
# 警告: 词语 '当校' 不在词向量模型中
# 警告: 词语 '斥责人' 不在词向量模型中
# 警告: 词语 '被组织者' 不在词向量模型中
# 警告: 词语 '波热闹' 不在词向量模型中
# 警告: 词语 '主体方' 不在词向量模型中
# 警告: 词语 '食客们' 不在词向量模型中
# 警告: 词语 '语冰' 不在词向量模型中
# 警告: 词语 '消遣强' 不在词向量模型中
# 警告: 词语 '暴力者们' 不在词向量模型中
# 警告: 词语 '清流嘴炮' 不在词向量模型中
# 警告: 词语 '陶崇园' 不在词向量模型中
# 警告: 词语 '李靓蕾' 不在词向量模型中
# 警告: 词语 '黑市委' 不在词向量模型中
# 警告: 词语 '答者' 不在词向量模型中
# 警告: 词语 '惡徒' 不在词向量模型中
# 警告: 词语 '神疑鬼' 不在词向量模型中
# 警告: 词语 '极端者' 不在词向量模型中
# 警告: 词语 '小白们' 不在词向量模型中
# 警告: 词语 '葛荣' 不在词向量模型中
# 警告: 词语 '网名们' 不在词向量模型中
# 警告: 词语 '流氓会' 不在词向量模型中
# 警告: 词语 '传销窝' 不在词向量模型中
# 警告: 词语 '满朝公卿' 不在词向量模型中
# 警告: 词语 '民怒' 不在词向量模型中
# 警告: 词语 '拦路匪' 不在词向量模型中
# 警告: 词语 '退役者' 不在词向量模型中
# 警告: 词语 '宁强县人' 不在词向量模型中
# 警告: 词语 '伙拼' 不在词向量模型中
# 警告: 词语 '回复者' 不在词向量模型中
# 警告: 词语 '行内人' 不在词向量模型中
# 警告: 词语 '顶替者' 不在词向量模型中
# 警告: 词语 '相似者' 不在词向量模型中
# 警告: 词语 '副县' 不在词向量模型中
# 警告: 词语 '正县级' 不在词向量模型中
# 警告: 词语 '孔令贻' 不在词向量模型中
# 警告: 词语 '神评' 不在词向量模型中
# 警告: 词语 '使枪人' 不在词向量模型中
# 警告: 词语 '栽总' 不在词向量模型中
# 警告: 词语 '经营人' 不在词向量模型中
# 警告: 词语 '逃逸者' 不在词向量模型中
# 警告: 词语 '皮渣子' 不在词向量模型中
# 警告: 词语 '雅典人' 不在词向量模型中
# 警告: 词语 '气生' 不在词向量模型中
# 警告: 词语 '开团' 不在词向量模型中
# 警告: 词语 '贵人们' 不在词向量模型中
# 警告: 词语 '供养者' 不在词向量模型中
# 警告: 词语 '聪明劲' 不在词向量模型中
# 警告: 词语 '怀化人' 不在词向量模型中
# 警告: 词语 '大青天' 不在词向量模型中
# 警告: 词语 '关员' 不在词向量模型中
# 警告: 词语 '信阳人' 不在词向量模型中
# 警告: 词语 '大白们' 不在词向量模型中
# 警告: 词语 '也纳人' 不在词向量模型中
# 警告: 词语 '大哲' 不在词向量模型中
# 警告: 词语 '蝇营' 不在词向量模型中
# 警告: 词语 '大人者' 不在词向量模型中
# 警告: 词语 '暴力分子' 不在词向量模型中
# 警告: 词语 '送伤者' 不在词向量模型中
# 警告: 词语 '家孩' 不在词向量模型中
# 警告: 词语 '卖命钱' 不在词向量模型中
# 警告: 词语 '王清远' 不在词向量模型中
# 警告: 词语 '解说人' 不在词向量模型中
# 警告: 词语 '金百万' 不在词向量模型中
# 警告: 词语 '娱乐圈儿' 不在词向量模型中
# 警告: 词语 '黑子们' 不在词向量模型中
# 警告: 词语 '看戏者' 不在词向量模型中
# 警告: 词语 '精人' 不在词向量模型中
# 警告: 词语 '苏联人' 不在词向量模型中
# 警告: 词语 '群儒' 不在词向量模型中
# 警告: 词语 '傲慢者' 不在词向量模型中
# 警告: 词语 '好辩者' 不在词向量模型中
# 警告: 词语 '受伤害者们' 不在词向量模型中
# 警告: 词语 '暴怒者' 不在词向量模型中
# 警告: 词语 '进狱风' 不在词向量模型中
# 警告: 词语 '牛马玩意' 不在词向量模型中
# 警告: 词语 '眼镜人' 不在词向量模型中
# 警告: 词语 '受众群' 不在词向量模型中
# 警告: 词语 '支持者们' 不在词向量模型中
# 警告: 词语 '美利坚人' 不在词向量模型中
# 警告: 词语 '拉架者' 不在词向量模型中
# 警告: 词语 '帮派会' 不在词向量模型中
# 警告: 词语 '高手们' 不在词向量模型中
# 警告: 词语 '教琴' 不在词向量模型中
# 警告: 词语 '一员' 不在词向量模型中
# 警告: 词语 '对派' 不在词向量模型中
# 警告: 词语 '烂鬼' 不在词向量模型中
# 警告: 词语 '捕快们' 不在词向量模型中
# 警告: 词语 '豪杰们' 不在词向量模型中
# 警告: 词语 '津唐辽' 不在词向量模型中
# 警告: 词语 '黑能手' 不在词向量模型中
# 警告: 词语 '屎盔子' 不在词向量模型中
# 警告: 词语 '同厕' 不在词向量模型中
# 警告: 词语 '华楠' 不在词向量模型中
# 警告: 词语 '孟瑞鹏' 不在词向量模型中
# 警告: 词语 '婉婷' 不在词向量模型中
# 警告: 词语 '父老妻儿' 不在词向量模型中
# 警告: 词语 '陈继某' 不在词向量模型中
# 警告: 词语 '范马勇' 不在词向量模型中
# 警告: 词语 '大仙儿' 不在词向量模型中
# 警告: 词语 '官推' 不在词向量模型中
# 警告: 词语 '张字' 不在词向量模型中
# 警告: 词语 '日民' 不在词向量模型中
# 警告: 词语 '好友圈' 不在词向量模型中
# 警告: 词语 '实习工' 不在词向量模型中
# 警告: 词语 '骚扰犯' 不在词向量模型中
# 警告: 词语 '家儿' 不在词向量模型中
# 警告: 词语 '储户们' 不在词向量模型中
# 警告: 词语 '捧红' 不在词向量模型中
# 警告: 词语 '街道人' 不在词向量模型中
# 警告: 词语 '乐观主义者' 不在词向量模型中
# 警告: 词语 '悲观主义者' 不在词向量模型中
# 警告: 词语 '供物员' 不在词向量模型中
# 警告: 词语 '叶万昌' 不在词向量模型中
# 警告: 词语 '微轻伤' 不在词向量模型中
# 警告: 词语 '刘志强' 不在词向量模型中
# 警告: 词语 '大长腿' 不在词向量模型中
# 警告: 词语 '庆嫂' 不在词向量模型中
# 警告: 词语 '玩应' 不在词向量模型中
# 警告: 词语 '杠精们' 不在词向量模型中
# 警告: 词语 '书委' 不在词向量模型中
# 警告: 词语 '韦舰长' 不在词向量模型中
# 警告: 词语 '校生' 不在词向量模型中
# 警告: 词语 '小丑们' 不在词向量模型中
# 警告: 词语 '马恩列斯毛' 不在词向量模型中
# 警告: 词语 '场裁' 不在词向量模型中
# 警告: 词语 '督监' 不在词向量模型中
# 警告: 词语 '散打手' 不在词向量模型中
# 警告: 词语 '百族' 不在词向量模型中
# 警告: 词语 '屌毛' 不在词向量模型中
# 警告: 词语 '拐卖犯' 不在词向量模型中
# 警告: 词语 '皖南人' 不在词向量模型中
# 警告: 词语 '江西人' 不在词向量模型中
# 警告: 词语 '拉黑人' 不在词向量模型中
# 警告: 词语 '政圈' 不在词向量模型中
# 警告: 词语 '建制派' 不在词向量模型中
# 警告: 词语 '中立者' 不在词向量模型中
# 警告: 词语 '砍手党' 不在词向量模型中
# 警告: 词语 '回怼' 不在词向量模型中
# 警告: 词语 '窃国者' 不在词向量模型中
# 警告: 词语 '毕业照' 不在词向量模型中
# 警告: 词语 '抖音带' 不在词向量模型中
# 警告: 词语 '队友们' 不在词向量模型中
# 警告: 词语 '西藏人' 不在词向量模型中
# 警告: 词语 '副秘书长' 不在词向量模型中
# 警告: 词语 '做恶者' 不在词向量模型中
# 警告: 词语 '仁民' 不在词向量模型中
# 警告: 词语 '写手们' 不在词向量模型中
# 警告: 词语 '安倍桑' 不在词向量模型中
# 警告: 词语 '一语' 不在词向量模型中
# 警告: 词语 '金陵王' 不在词向量模型中
# 警告: 词语 '贴主' 不在词向量模型中
# 警告: 词语 '失道者' 不在词向量模型中
# 警告: 词语 '网喷' 不在词向量模型中
# 警告: 词语 '群伤' 不在词向量模型中
# 警告: 词语 '大才' 不在词向量模型中
# 警告: 词语 '驴人' 不在词向量模型中
# 警告: 词语 '降临派' 不在词向量模型中
# 警告: 词语 '不理智' 不在词向量模型中
# 警告: 词语 '私力救济' 不在词向量模型中
# 警告: 词语 '圣人们' 不在词向量模型中
# 警告: 词语 '迫害者' 不在词向量模型中
# 警告: 词语 '歧视者' 不在词向量模型中
# 警告: 词语 '大胖子' 不在词向量模型中
# 警告: 词语 '乘客犯' 不在词向量模型中
# 警告: 词语 '洗地费' 不在词向量模型中
# 警告: 词语 '脚踹' 不在词向量模型中
# 警告: 词语 '理解派' 不在词向量模型中
# 警告: 词语 '大法党们' 不在词向量模型中
# 警告: 词语 '傻弔' 不在词向量模型中
# 警告: 词语 '点赞者' 不在词向量模型中
# 警告: 词语 '大张伟' 不在词向量模型中
# 警告: 词语 '逃犯人' 不在词向量模型中
# 警告: 词语 '区分局长' 不在词向量模型中
# 警告: 词语 '网逃' 不在词向量模型中
# 警告: 词语 '轮眼' 不在词向量模型中
# 警告: 词语 '基本人' 不在词向量模型中
# 警告: 词语 '客们' 不在词向量模型中
# 警告: 词语 '弱民' 不在词向量模型中
# 警告: 词语 '传谣者' 不在词向量模型中
# 警告: 词语 '偏黑除恶' 不在词向量模型中
# 警告: 词语 '卫道士们' 不在词向量模型中
# 警告: 词语 '管家们' 不在词向量模型中
# 警告: 词语 '暴力狂' 不在词向量模型中
# 警告: 词语 '李钊' 不在词向量模型中
# 警告: 词语 '点心员' 不在词向量模型中
# 警告: 词语 '老一輩' 不在词向量模型中
# 警告: 词语 '別人' 不在词向量模型中
# 警告: 词语 '保镖团' 不在词向量模型中
# 警告: 词语 '张鱼' 不在词向量模型中
# 警告: 词语 '報警人' 不在词向量模型中
# 警告: 词语 '口罩侠' 不在词向量模型中
# 警告: 词语 '尾田仔' 不在词向量模型中
# 警告: 词语 '大反派' 不在词向量模型中
# 警告: 词语 '小地痞' 不在词向量模型中
# 警告: 词语 '伤害方' 不在词向量模型中
# 警告: 词语 '黑混们' 不在词向量模型中
# 警告: 词语 '侠者' 不在词向量模型中
# 警告: 词语 '卖锅' 不在词向量模型中
# 警告: 词语 '当义人' 不在词向量模型中
# 警告: 词语 '侠肝' 不在词向量模型中
# 警告: 词语 '公民们' 不在词向量模型中
# 警告: 词语 '开武馆' 不在词向量模型中
# 警告: 词语 '体育圈' 不在词向量模型中
# 警告: 词语 '大咖儿' 不在词向量模型中
# 警告: 词语 '商家们' 不在词向量模型中
# 警告: 词语 '大娃' 不在词向量模型中
# 警告: 词语 '二娃' 不在词向量模型中
# 警告: 词语 '可路人' 不在词向量模型中
# 警告: 词语 '人成龙' 不在词向量模型中
# 警告: 词语 '傻福' 不在词向量模型中
# 警告: 词语 '土贼' 不在词向量模型中
# 警告: 词语 '团工委' 不在词向量模型中
# 警告: 词语 '快手大仙' 不在词向量模型中
# 警告: 词语 '三下不乱' 不在词向量模型中
# 警告: 词语 '人亡' 不在词向量模型中
# 警告: 词语 '自私用' 不在词向量模型中
# 警告: 词语 '海扁侠' 不在词向量模型中
# 警告: 词语 '钞能力' 不在词向量模型中
# 警告: 词语 '圈言' 不在词向量模型中
# 警告: 词语 '圈语' 不在词向量模型中
# 警告: 词语 '成龙大哥' 不在词向量模型中
# 警告: 词语 '傻批' 不在词向量模型中
# 警告: 词语 '晶哥' 不在词向量模型中
# 警告: 词语 '牧民们' 不在词向量模型中
# 警告: 词语 '恭俭' 不在词向量模型中
# 警告: 词语 '贵己' 不在词向量模型中
# 警告: 词语 '正义人' 不在词向量模型中
# 警告: 词语 '宗亲会' 不在词向量模型中
# 警告: 词语 '大律' 不在词向量模型中
# 警告: 词语 '互联网人' 不在词向量模型中
# 警告: 词语 '二人组' 不在词向量模型中
# 警告: 词语 '黑白俩道' 不在词向量模型中
# 警告: 词语 '迷彩服人员' 不在词向量模型中
# 警告: 词语 '群伙' 不在词向量模型中
# 警告: 词语 '渔老大' 不在词向量模型中
# 警告: 词语 '曝光者' 不在词向量模型中
# 警告: 词语 '本尊' 不在词向量模型中
# 警告: 词语 '公道人' 不在词向量模型中
# 警告: 词语 '黑粉头子' 不在词向量模型中
# 警告: 词语 '乎儿们' 不在词向量模型中
# 警告: 词语 '粉丝圈' 不在词向量模型中
# 警告: 词语 '酸人' 不在词向量模型中
# 警告: 词语 '张家界人' 不在词向量模型中
# 警告: 词语 '小众生' 不在词向量模型中
# 警告: 词语 '晋爵' 不在词向量模型中
# 警告: 词语 '大伞们' 不在词向量模型中
# 警告: 词语 '冀春雷' 不在词向量模型中
# 警告: 词语 '乡党型' 不在词向量模型中
# 警告: 词语 '完美主义者' 不在词向量模型中
# 警告: 词语 '楼猪' 不在词向量模型中
# 警告: 词语 '毛呵' 不在词向量模型中
# 警告: 词语 '眷样' 不在词向量模型中
# 警告: 词语 '被虐者' 不在词向量模型中
# 警告: 词语 '烂片王' 不在词向量模型中
# 警告: 词语 '仆从们' 不在词向量模型中
# 警告: 词语 '效仿者' 不在词向量模型中
# 警告: 词语 '张哲瀚' 不在词向量模型中
# 警告: 词语 '椿椿' 不在词向量模型中
# 警告: 词语 '陈烁' 不在词向量模型中
# 警告: 词语 '进重症' 不在词向量模型中
# 警告: 词语 '狠辣阴险' 不在词向量模型中
# 警告: 词语 '肌肉块' 不在词向量模型中
# 警告: 词语 '暴力份子' 不在词向量模型中
# 警告: 词语 '单棍' 不在词向量模型中
# 警告: 词语 '刀笔吏' 不在词向量模型中
# 警告: 词语 '人秀' 不在词向量模型中
# 警告: 词语 '老本地人' 不在词向量模型中
# 警告: 词语 '警黑' 不在词向量模型中
# 警告: 词语 '非自己人' 不在词向量模型中
# 警告: 词语 '郑伯克' 不在词向量模型中
# 警告: 词语 '段于鄢' 不在词向量模型中
# 警告: 词语 '邢涛' 不在词向量模型中
# 警告: 词语 '李树军' 不在词向量模型中
# 警告: 词语 '苗德成' 不在词向量模型中
# 警告: 词语 '专班' 不在词向量模型中
# 警告: 词语 '咸鱼党' 不在词向量模型中
# 警告: 词语 '关之檀' 不在词向量模型中
# 警告: 词语 '官員' 不在词向量模型中
# 警告: 词语 '教育队' 不在词向量模型中
# 警告: 词语 '领导局' 不在词向量模型中
# 警告: 词语 '司徒家' 不在词向量模型中
# 警告: 词语 '社鼠' 不在词向量模型中
# 警告: 词语 '欧心虎' 不在词向量模型中
# 警告: 词语 '父母官们' 不在词向量模型中
# 警告: 词语 '老友们' 不在词向量模型中
# 警告: 词语 '薇娅' 不在词向量模型中
# 警告: 词语 '挖墓人' 不在词向量模型中
# 警告: 词语 '李丰田' 不在词向量模型中
# 警告: 词语 '公权利' 不在词向量模型中
# 警告: 词语 '键盘数' 不在词向量模型中
# 警告: 词语 '李勇会' 不在词向量模型中
# 警告: 词语 '漠叔' 不在词向量模型中
# 警告: 词语 '武警队' 不在词向量模型中
# 警告: 词语 '谭乔' 不在词向量模型中
# 警告: 词语 '喷沙棍' 不在词向量模型中
# 警告: 词语 '独苗苗' 不在词向量模型中
# 警告: 词语 '陈武学' 不在词向量模型中
# 警告: 词语 '法徒' 不在词向量模型中
# 警告: 词语 '帮凶作用' 不在词向量模型中
# 警告: 词语 '面门子' 不在词向量模型中
# 警告: 词语 '长舌街溜子' 不在词向量模型中
# 警告: 词语 '柔王' 不在词向量模型中
# 警告: 词语 '曹志华' 不在词向量模型中
# 警告: 词语 '狗屁用' 不在词向量模型中
# 警告: 词语 '邻导' 不在词向量模型中
# 警告: 词语 '虞某某' 不在词向量模型中
# 警告: 词语 '前辈们' 不在词向量模型中
# 警告: 词语 '酒客们' 不在词向量模型中
# 警告: 词语 '吃瓜人' 不在词向量模型中
# 警告: 词语 '中央人' 不在词向量模型中
# 警告: 词语 '持刀权' 不在词向量模型中
# 警告: 词语 '说话人' 不在词向量模型中
# 警告: 词语 '扫地工' 不在词向量模型中
# 警告: 词语 '登录人' 不在词向量模型中
# 警告: 词语 '侠应' 不在词向量模型中
# 警告: 词语 '人员们' 不在词向量模型中
# 警告: 词语 '侦破方' 不在词向量模型中
# 警告: 词语 '超市侠' 不在词向量模型中
# 警告: 词语 '补充人' 不在词向量模型中
# 警告: 词语 '骚年' 不在词向量模型中
# 警告: 词语 '传谣者们' 不在词向量模型中
# 警告: 词语 '检法院长' 不在词向量模型中
# 警告: 词语 '关联人' 不在词向量模型中
# 警告: 词语 '友关' 不在词向量模型中
# 警告: 词语 '补门' 不在词向量模型中
# 警告: 词语 '文昭' 不在词向量模型中
# 警告: 词语 '惠者' 不在词向量模型中
# 警告: 词语 '精明者' 不在词向量模型中
# 警告: 词语 '公知权' 不在词向量模型中
# 警告: 词语 '光明所' 不在词向量模型中
# 警告: 词语 '马宝国' 不在词向量模型中
# 警告: 词语 '市局长' 不在词向量模型中
# 警告: 词语 '屁脑子' 不在词向量模型中
# 警告: 词语 '徐长元' 不在词向量模型中
# 警告: 词语 '非体育生' 不在词向量模型中
# 警告: 词语 '黄丝' 不在词向量模型中
# 警告: 词语 '洋奴们' 不在词向量模型中
# 警告: 词语 '阿美利卡' 不在词向量模型中
# 警告: 词语 '坚定方' 不在词向量模型中
# 警告: 词语 '司法桔' 不在词向量模型中
# 警告: 词语 '丑国人' 不在词向量模型中
# 警告: 词语 '麻蛋' 不在词向量模型中
# 警告: 词语 '晒娃' 不在词向量模型中
# 警告: 词语 '三观不正' 不在词向量模型中
# 警告: 词语 '自肃' 不在词向量模型中
# 警告: 词语 '水军图' 不在词向量模型中
# 警告: 词语 '暴民们' 不在词向量模型中
# 警告: 词语 '布鲁斯李' 不在词向量模型中
# 警告: 词语 '盗国者' 不在词向量模型中
# 警告: 词语 '涨粉' 不在词向量模型中
# 警告: 词语 '护受害者' 不在词向量模型中
# 警告: 词语 '店家们' 不在词向量模型中
# 警告: 词语 '店客们' 不在词向量模型中
# 警告: 词语 '法奸们' 不在词向量模型中
# 警告: 词语 '特权者' 不在词向量模型中
# 警告: 词语 '抵抗军' 不在词向量模型中
# 警告: 词语 '目击者们' 不在词向量模型中
# 警告: 词语 '销售岗' 不在词向量模型中
# 警告: 词语 '不见义勇为' 不在词向量模型中
# 警告: 词语 '可谴责性' 不在词向量模型中
# 警告: 词语 '施助者' 不在词向量模型中
# 警告: 词语 '昆山龙' 不在词向量模型中
# 警告: 词语 '刷差评' 不在词向量模型中
# 警告: 词语 '网喷们' 不在词向量模型中
# 警告: 词语 '蠢贼们' 不在词向量模型中
# 警告: 词语 '小兵小将' 不在词向量模型中
# 警告: 词语 '脑残货' 不在词向量模型中
# 警告: 词语 '最右边' 不在词向量模型中
# 警告: 词语 '使者们' 不在词向量模型中
# 警告: 词语 '大神先知' 不在词向量模型中
# 警告: 词语 '臭傻' 不在词向量模型中
# 警告: 词语 '学者们' 不在词向量模型中
# 警告: 词语 '懦弱者' 不在词向量模型中
# 警告: 词语 '周围人' 不在词向量模型中
# 警告: 词语 '凶面' 不在词向量模型中
# 警告: 词语 '乌鸦哥' 不在词向量模型中
# 警告: 词语 '好人们' 不在词向量模型中
# 警告: 词语 '键盘侠群' 不在词向量模型中
# 警告: 词语 '乐子党' 不在词向量模型中
# 警告: 词语 '江粉' 不在词向量模型中
# 警告: 词语 '灰吧' 不在词向量模型中
# 警告: 词语 '纯黑道' 不在词向量模型中
# 警告: 词语 '国民党徒' 不在词向量模型中
# 警告: 词语 '九兽' 不在词向量模型中
# 警告: 词语 '风暴眼' 不在词向量模型中
# 警告: 词语 '小毛贼' 不在词向量模型中
# 警告: 词语 '偷狗贼' 不在词向量模型中
# 警告: 词语 '听战报' 不在词向量模型中
# 警告: 词语 '装片' 不在词向量模型中
# 警告: 词语 '战士们' 不在词向量模型中
# 警告: 词语 '文职部' 不在词向量模型中
# 警告: 词语 '表演型' 不在词向量模型中
# 警告: 词语 '大喽啰' 不在词向量模型中
# 警告: 词语 '地头蛇们' 不在词向量模型中
# 警告: 词语 '文活' 不在词向量模型中
# 警告: 词语 '马福报' 不在词向量模型中
# 警告: 词语 '健盘侠' 不在词向量模型中
# 警告: 词语 '宠孩' 不在词向量模型中
# 警告: 词语 '孽息' 不在词向量模型中
# 警告: 词语 '撒匪' 不在词向量模型中
# 警告: 词语 '大黑大恶' 不在词向量模型中
# 警告: 词语 '大午' 不在词向量模型中
# 警告: 词语 '潘凤可' 不在词向量模型中
# 警告: 词语 '敌寡友' 不在词向量模型中
# 警告: 词语 '唐西哥' 不在词向量模型中
# 警告: 词语 '组织会' 不在词向量模型中
# 警告: 词语 '官身' 不在词向量模型中
# 警告: 词语 '带师' 不在词向量模型中
# 警告: 词语 '面像' 不在词向量模型中
# 警告: 词语 '乡霸' 不在词向量模型中
# 警告: 词语 '有害人' 不在词向量模型中
# 警告: 词语 '中东人' 不在词向量模型中
# 警告: 词语 '借头' 不在词向量模型中
# 警告: 词语 '黑社' 不在词向量模型中
# 警告: 词语 '站高点' 不在词向量模型中
# 警告: 词语 '吉米仔' 不在词向量模型中
# 警告: 词语 '少先' 不在词向量模型中
# 警告: 词语 '老字辈' 不在词向量模型中
# 警告: 词语 '行各业' 不在词向量模型中
# 警告: 词语 '势力们' 不在词向量模型中
# 警告: 词语 '三把手' 不在词向量模型中
# 警告: 词语 '畜牲们' 不在词向量模型中
# 警告: 词语 '官大爷' 不在词向量模型中
# 警告: 词语 '坏人们' 不在词向量模型中
# 警告: 词语 '法盲带' 不在词向量模型中
# 警告: 词语 '善良人' 不在词向量模型中
# 警告: 词语 '报们' 不在词向量模型中
# 警告: 词语 '感情军' 不在词向量模型中
# 警告: 词语 '涉黑人' 不在词向量模型中
# 警告: 词语 '督战队' 不在词向量模型中
# 警告: 词语 '人渣子' 不在词向量模型中
# 警告: 词语 '党滴' 不在词向量模型中
# 警告: 词语 '光昂辉' 不在词向量模型中
# 警告: 词语 '蒙哥大汗' 不在词向量模型中
# 警告: 词语 '王二奶奶' 不在词向量模型中
# 警告: 词语 '公安察' 不在词向量模型中
# 警告: 词语 '苏凡' 不在词向量模型中
# 警告: 词语 '史王' 不在词向量模型中
# 警告: 词语 '失信者' 不在词向量模型中
# 警告: 词语 '管道局' 不在词向量模型中
# 警告: 词语 '水军号' 不在词向量模型中
# 警告: 词语 '受害面' 不在词向量模型中
# 警告: 词语 '嗨涩会' 不在词向量模型中
# 警告: 词语 '普车工' 不在词向量模型中
# 警告: 词语 '普铣工' 不在词向量模型中
# 警告: 词语 '插床工' 不在词向量模型中
# 警告: 词语 '季组团' 不在词向量模型中
# 警告: 词语 '贾敬龙' 不在词向量模型中
# 警告: 词语 '尼马' 不在词向量模型中
# 警告: 词语 '懦民' 不在词向量模型中
# 警告: 词语 '企业家们' 不在词向量模型中
# 警告: 词语 '某某子' 不在词向量模型中
# 警告: 词语 '人畜无害' 不在词向量模型中
# 警告: 词语 '居心可疑' 不在词向量模型中
# 警告: 词语 '民国人' 不在词向量模型中
# 警告: 词语 '大忠名臣' 不在词向量模型中
# 警告: 词语 '现场者' 不在词向量模型中
# 警告: 词语 '离谱者' 不在词向量模型中
# 警告: 词语 '新生代们' 不在词向量模型中
# 警告: 词语 '寻衅者' 不在词向量模型中
# 警告: 词语 '键盘哥' 不在词向量模型中
# 警告: 词语 '血偿' 不在词向量模型中
# 警告: 词语 '营级' 不在词向量模型中
# 警告: 词语 '群纵' 不在词向量模型中
# 警告: 词语 '个匪' 不在词向量模型中
# 警告: 词语 '雅库扎' 不在词向量模型中
# 警告: 词语 '网宣' 不在词向量模型中
# 警告: 词语 '举报侠' 不在词向量模型中
# 警告: 词语 '市人' 不在词向量模型中
# 警告: 词语 '程维高' 不在词向量模型中
# 警告: 词语 '刘玉锟' 不在词向量模型中
# 警告: 词语 '举报者们' 不在词向量模型中
# 警告: 词语 '送头鸟' 不在词向量模型中
# 警告: 词语 '夏想' 不在词向量模型中
# 警告: 词语 '冰阔洛' 不在词向量模型中
# 警告: 词语 '低官' 不在词向量模型中
# 警告: 词语 '鱼小虾' 不在词向量模型中
# 警告: 词语 '废掏肛狗' 不在词向量模型中
# 警告: 词语 '狗们' 不在词向量模型中
# 警告: 词语 '白背心' 不在词向量模型中
# 警告: 词语 '浴皇大帝' 不在词向量模型中
# 警告: 词语 '藤原浩' 不在词向量模型中
# 警告: 词语 '侯局森' 不在词向量模型中
# 警告: 词语 '巨土' 不在词向量模型中
# 警告: 词语 '官员类' 不在词向量模型中
# 警告: 词语 '二混子' 不在词向量模型中
# 警告: 词语 '德国党' 不在词向量模型中
# 警告: 词语 '猿神' 不在词向量模型中
# 警告: 词语 '街娃' 不在词向量模型中
# 警告: 词语 '小大哥' 不在词向量模型中
# 警告: 词语 '納粹' 不在词向量模型中
# 警告: 词语 '批评家们' 不在词向量模型中
# 警告: 词语 '滦南县人' 不在词向量模型中
# 警告: 词语 '市区人' 不在词向量模型中
# 警告: 词语 '别秀' 不在词向量模型中
# 警告: 词语 '坐班族' 不在词向量模型中
# 警告: 词语 '年经人' 不在词向量模型中
# 警告: 词语 '丫个' 不在词向量模型中
# 警告: 词语 '指使者' 不在词向量模型中
# 警告: 词语 '蛀虫们' 不在词向量模型中
# 警告: 词语 '主嫌疑人' 不在词向量模型中
# 警告: 词语 '站角' 不在词向量模型中
# 警告: 词语 '唐纳德特朗普' 不在词向量模型中
# 警告: 词语 '爱酱' 不在词向量模型中
# 警告: 词语 '刮民党' 不在词向量模型中
# 警告: 词语 '指导组' 不在词向量模型中
# 警告: 词语 '心大' 不在词向量模型中
# 警告: 词语 '地方人' 不在词向量模型中
# 警告: 词语 '良者' 不在词向量模型中
# 警告: 词语 '干饭人' 不在词向量模型中
# 警告: 词语 '事儿者' 不在词向量模型中
# 警告: 词语 '团伙罪' 不在词向量模型中
# 警告: 词语 '人家局' 不在词向量模型中
# 警告: 词语 '值班长' 不在词向量模型中
# 警告: 词语 '黑恶份子' 不在词向量模型中
# 警告: 词语 '芸芸众生们' 不在词向量模型中
# 警告: 词语 '巡警班' 不在词向量模型中
# 警告: 词语 '赵利坚' 不在词向量模型中
# 警告: 词语 '接警单' 不在词向量模型中
# 警告: 词语 '老毛子' 不在词向量模型中
# 警告: 词语 '三儿' 不在词向量模型中
# 警告: 词语 '巡防员' 不在词向量模型中
# 警告: 词语 '麻爪儿' 不在词向量模型中
# 警告: 词语 '从善' 不在词向量模型中
# 警告: 词语 '主练长' 不在词向量模型中
# 警告: 词语 '辩识力' 不在词向量模型中
# 警告: 词语 '小怪' 不在词向量模型中
# 警告: 词语 '淫销' 不在词向量模型中
# 警告: 词语 '吊数' 不在词向量模型中
# 警告: 词语 '玩命徒' 不在词向量模型中
# 警告: 词语 '拳迷' 不在词向量模型中
# 警告: 词语 '糊脸' 不在词向量模型中
# 警告: 词语 '拳商' 不在词向量模型中
# 警告: 词语 '怹萱' 不在词向量模型中
# 警告: 词语 '冀八毛' 不在词向量模型中
# 警告: 词语 '夜摊摊' 不在词向量模型中
# 警告: 词语 '老帕们' 不在词向量模型中
# 警告: 词语 '死战犯' 不在词向量模型中
# 警告: 词语 '九零后' 不在词向量模型中
# 警告: 词语 '公共安' 不在词向量模型中
# 警告: 词语 '廊坊民不聊生' 不在词向量模型中
# 警告: 词语 '少年们' 不在词向量模型中
# 警告: 词语 '后台们' 不在词向量模型中
# 警告: 词语 '李玟靓' 不在词向量模型中
# 警告: 词语 '对答者' 不在词向量模型中
# 警告: 词语 '关内人' 不在词向量模型中
# 警告: 词语 '黑苏' 不在词向量模型中
# 警告: 词语 '情兽' 不在词向量模型中
# 警告: 词语 '黑衣黄毛' 不在词向量模型中
# 警告: 词语 '民恨' 不在词向量模型中
# 警告: 词语 '德意志人' 不在词向量模型中
# 警告: 词语 '吃饭人' 不在词向量模型中
# 警告: 词语 '雨言' 不在词向量模型中
# 警告: 词语 '副领导' 不在词向量模型中
# 警告: 词语 '小伙们' 不在词向量模型中
# 警告: 词语 '撞墙者' 不在词向量模型中
# 警告: 词语 '刀锋寨' 不在词向量模型中
# 警告: 词语 '人技' 不在词向量模型中
# 警告: 词语 '自述者' 不在词向量模型中
# 警告: 词语 '第子们' 不在词向量模型中
# 警告: 词语 '得好人' 不在词向量模型中
# 警告: 词语 '袖手旁观者' 不在词向量模型中
# 警告: 词语 '相助者' 不在词向量模型中
# 警告: 词语 '子观音' 不在词向量模型中
# 警告: 词语 '胆小者' 不在词向量模型中
# 警告: 词语 '戴南镇人' 不在词向量模型中
# 警告: 词语 '谭可' 不在词向量模型中
# 警告: 词语 '王久宗' 不在词向量模型中
# 警告: 词语 '李晓军' 不在词向量模型中
# 警告: 词语 '方诚毅' 不在词向量模型中
# 警告: 词语 '张郃' 不在词向量模型中
# 警告: 词语 '兰室' 不在词向量模型中
# 警告: 词语 '平凡者' 不在词向量模型中
# 警告: 词语 '商户群' 不在词向量模型中
# 警告: 词语 '肓流子' 不在词向量模型中
# 警告: 词语 '贼棒' 不在词向量模型中
# 警告: 词语 '民膏民脂' 不在词向量模型中
# 警告: 词语 '红码案' 不在词向量模型中
# 警告: 词语 '忍民' 不在词向量模型中
# 警告: 词语 '簧舌' 不在词向量模型中
# 警告: 词语 '贵圈' 不在词向量模型中
# 警告: 词语 '房事虫' 不在词向量模型中
# 警告: 词语 '春春' 不在词向量模型中
# 警告: 词语 '阻碍者' 不在词向量模型中
# 警告: 词语 '软茬' 不在词向量模型中
# 警告: 词语 '族名' 不在词向量模型中
# 警告: 词语 '保安处' 不在词向量模型中
# 警告: 词语 '挨打者' 不在词向量模型中
# 警告: 词语 '鬼样子' 不在词向量模型中
# 警告: 词语 '王德滨' 不在词向量模型中
# 警告: 词语 '被打方' 不在词向量模型中
# 警告: 词语 '权益者' 不在词向量模型中
# 警告: 词语 '傻货' 不在词向量模型中
# 警告: 词语 '高阶级' 不在词向量模型中
# 警告: 词语 '富豪们' 不在词向量模型中
# 警告: 词语 '社毒' 不在词向量模型中
# 警告: 词语 '流氓犯' 不在词向量模型中
# 警告: 词语 '洗地者' 不在词向量模型中
# 警告: 词语 '粉卫兵' 不在词向量模型中
# 警告: 词语 '仇国者' 不在词向量模型中
# 警告: 词语 '轻伤害' 不在词向量模型中
# 警告: 词语 '有智之士' 不在词向量模型中
# 警告: 词语 '人罩' 不在词向量模型中
# 警告: 词语 '中医黑' 不在词向量模型中
# 警告: 词语 '制定者们' 不在词向量模型中
# 警告: 词语 '程继志' 不在词向量模型中
# 警告: 词语 '里星爷' 不在词向量模型中
# 警告: 词语 '法盲强' 不在词向量模型中
# 警告: 词语 '危重症' 不在词向量模型中
# 警告: 词语 '拳拳们' 不在词向量模型中
# 警告: 词语 '作证人' 不在词向量模型中
# 警告: 词语 '大伞云云' 不在词向量模型中
# 警告: 词语 '記者' 不在词向量模型中
# 警告: 词语 '作文儿' 不在词向量模型中
# 警告: 词语 '陈欣然' 不在词向量模型中
# 警告: 词语 '无脑喷' 不在词向量模型中
# 警告: 词语 '治安者' 不在词向量模型中
# 警告: 词语 '易煽动性' 不在词向量模型中
# 警告: 词语 '非发言人' 不在词向量模型中
# 警告: 词语 '武术家们' 不在词向量模型中
# 警告: 词语 '二人黑' 不在词向量模型中
# 警告: 词语 '傻波' 不在词向量模型中
# 警告: 词语 '伟法' 不在词向量模型中
# 警告: 词语 '牛鬼蛇神们' 不在词向量模型中
# 警告: 词语 '赌路人' 不在词向量模型中
# 警告: 词语 '瘦猴' 不在词向量模型中
# 警告: 词语 '热血未冷' 不在词向量模型中
# 警告: 词语 '內心' 不在词向量模型中
# 警告: 词语 '钱劳' 不在词向量模型中
# 警告: 词语 '被帮者' 不在词向量模型中
# 警告: 词语 '小八嘎' 不在词向量模型中
# 警告: 词语 '遭遇者' 不在词向量模型中
# 警告: 词语 '黒社会' 不在词向量模型中
# 警告: 词语 '公关界' 不在词向量模型中
# 警告: 词语 '不法者' 不在词向量模型中
# 警告: 词语 '访者' 不在词向量模型中
# 警告: 词语 '人性骚扰' 不在词向量模型中
# 警告: 词语 '答主们' 不在词向量模型中
# 警告: 词语 '无罪者' 不在词向量模型中
# 警告: 词语 '团伙人' 不在词向量模型中
# 警告: 词语 '医从文' 不在词向量模型中
# 警告: 词语 '受迫害者' 不在词向量模型中
# 警告: 词语 '笨比' 不在词向量模型中
# 警告: 词语 '帮理' 不在词向量模型中
# 警告: 词语 '下棋人' 不在词向量模型中
# 警告: 词语 '权师' 不在词向量模型中
# 警告: 词语 '阿彌陀佛' 不在词向量模型中
# 警告: 词语 '魔球迷' 不在词向量模型中
# 警告: 词语 '某权们' 不在词向量模型中
# 警告: 词语 '阿美利坚' 不在词向量模型中
# 警告: 词语 '老牛仔们' 不在词向量模型中
# 警告: 词语 '习法者' 不在词向量模型中
# 警告: 词语 '受虐症' 不在词向量模型中
# 警告: 词语 '付费群' 不在词向量模型中
# 警告: 词语 '朋友斧正' 不在词向量模型中
# 警告: 词语 '鄙視鏈' 不在词向量模型中
# 警告: 词语 '處境' 不在词向量模型中
# 警告: 词语 '少中之少' 不在词向量模型中
# 警告: 词语 '哪根筋' 不在词向量模型中
# 警告: 词语 '外面人' 不在词向量模型中
# 警告: 词语 '慈老' 不在词向量模型中
# 警告: 词语 '红脸男' 不在词向量模型中
# 警告: 词语 '奴民' 不在词向量模型中
# 警告: 词语 '清醒人' 不在词向量模型中
# 警告: 词语 '猪头猪脑' 不在词向量模型中
# 警告: 词语 '数字处' 不在词向量模型中
# 警告: 词语 '牛啤' 不在词向量模型中
# 警告: 词语 '正义欲' 不在词向量模型中
# 警告: 词语 '闹谈' 不在词向量模型中
# 警告: 词语 '主检法' 不在词向量模型中
# 警告: 词语 '法医官' 不在词向量模型中
# 警告: 词语 '八卦心' 不在词向量模型中
# 警告: 词语 '理解度' 不在词向量模型中
# 警告: 词语 '卤克文' 不在词向量模型中
# 警告: 词语 '副所' 不在词向量模型中
# 警告: 词语 '嫌疑犯们' 不在词向量模型中
# 警告: 词语 '网安' 不在词向量模型中
# 警告: 词语 '剑徒' 不在词向量模型中
# 警告: 词语 '世家们' 不在词向量模型中
# 警告: 词语 '狗腿子们' 不在词向量模型中
# 警告: 词语 '人头地' 不在词向量模型中
# 警告: 词语 '顾左右' 不在词向量模型中
# 警告: 词语 '本侠' 不在词向量模型中
# 警告: 词语 '体系人' 不在词向量模型中
# 警告: 词语 '受信者' 不在词向量模型中
# 警告: 词语 '冷静派' 不在词向量模型中
# 警告: 词语 '顶包' 不在词向量模型中
# 警告: 词语 '灰衬衫' 不在词向量模型中
# 警告: 词语 '大耳' 不在词向量模型中
# 警告: 词语 '明星双标' 不在词向量模型中
# 警告: 词语 '管者' 不在词向量模型中
# 警告: 词语 '缩头龟' 不在词向量模型中
# 警告: 词语 '顺风团' 不在词向量模型中
# 警告: 词语 '知命者' 不在词向量模型中
# 警告: 词语 '圈仔' 不在词向量模型中
# 警告: 词语 '势众' 不在词向量模型中
# 警告: 词语 '混手' 不在词向量模型中
# 警告: 词语 '知名人' 不在词向量模型中
# 警告: 词语 '绝丁' 不在词向量模型中
# 警告: 词语 '沈万' 不在词向量模型中
# 警告: 词语 '键盘者' 不在词向量模型中
# 警告: 词语 '狱敌' 不在词向量模型中
# 警告: 词语 '現代人' 不在词向量模型中
# 警告: 词语 '娛樂圈' 不在词向量模型中
# 警告: 词语 '腦袋' 不在词向量模型中
# 警告: 词语 '鍵盤俠' 不在词向量模型中
# 警告: 词语 '醉熊' 不在词向量模型中
# 警告: 词语 '墮落' 不在词向量模型中
# 警告: 词语 '黑号' 不在词向量模型中
# 警告: 词语 '群體' 不在词向量模型中
# 警告: 词语 '美國人' 不在词向量模型中
# 警告: 词语 '粉絲' 不在词向量模型中
# 警告: 词语 '军记' 不在词向量模型中
# 警告: 词语 '旁边人' 不在词向量模型中
# 警告: 词语 '槓精' 不在词向量模型中
# 警告: 词语 '炊龙哥' 不在词向量模型中
# 警告: 词语 '后辈们' 不在词向量模型中
# 警告: 词语 '上面人' 不在词向量模型中
# 警告: 词语 '卡塔昌' 不在词向量模型中
# 警告: 词语 '体校生' 不在词向量模型中
# 警告: 词语 '瘦娃' 不在词向量模型中
# 警告: 词语 '叽歪' 不在词向量模型中
# 警告: 词语 '民兵队' 不在词向量模型中
# 警告: 词语 '广西兵' 不在词向量模型中
# 警告: 词语 '典韦' 不在词向量模型中
# 警告: 词语 '护士美' 不在词向量模型中
# 警告: 词语 '永稚' 不在词向量模型中
# 警告: 词语 '南充人' 不在词向量模型中
# 警告: 词语 '历史学家们' 不在词向量模型中
# 警告: 词语 '正台子' 不在词向量模型中
# 警告: 词语 '骨折者' 不在词向量模型中
# 警告: 词语 '达华' 不在词向量模型中
# 警告: 词语 '许丽娜' 不在词向量模型中
# 警告: 词语 '十三燕' 不在词向量模型中
# 警告: 词语 '张翠山' 不在词向量模型中
# 警告: 词语 '杜易' 不在词向量模型中
# 警告: 词语 '传销人' 不在词向量模型中
# 警告: 词语 '狗杂碎' 不在词向量模型中
# 警告: 词语 '诈骗团' 不在词向量模型中
# 警告: 词语 '狠角' 不在词向量模型中
# 警告: 词语 '锁嗨' 不在词向量模型中
# 警告: 词语 '三口组' 不在词向量模型中
# 警告: 词语 '陈级志' 不在词向量模型中
# 警告: 词语 '库管' 不在词向量模型中
# 警告: 词语 '人珉' 不在词向量模型中
# 警告: 词语 '周震南' 不在词向量模型中
# 警告: 词语 '失职者' 不在词向量模型中
# 警告: 词语 '特殊科' 不在词向量模型中
# 警告: 词语 '洗脑奴性' 不在词向量模型中
# 警告: 词语 '获救者' 不在词向量模型中
# 警告: 词语 '情杀案' 不在词向量模型中
# 警告: 词语 '凶杀情杀案' 不在词向量模型中
# 警告: 词语 '紙片人' 不在词向量模型中
# 警告: 词语 '旧罪' 不在词向量模型中
# 警告: 词语 '二啥子' 不在词向量模型中
# 警告: 词语 '刑事者' 不在词向量模型中
# 警告: 词语 '渣学生' 不在词向量模型中
# 警告: 词语 '好事好人' 不在词向量模型中
# 警告: 词语 '达瓦里氏' 不在词向量模型中
# 警告: 词语 '校察' 不在词向量模型中
# 警告: 词语 '拦拦' 不在词向量模型中
# 警告: 词语 '逆天人' 不在词向量模型中
# 警告: 词语 '哈兄' 不在词向量模型中
# 警告: 词语 '战友们' 不在词向量模型中
# 警告: 词语 '人方' 不在词向量模型中
# 警告: 词语 '怂点' 不在词向量模型中
# 警告: 词语 '醉鬼流氓' 不在词向量模型中
# 警告: 词语 '暴行者' 不在词向量模型中
# 警告: 词语 '上鬼' 不在词向量模型中
# 警告: 词语 '混人' 不在词向量模型中
# 警告: 词语 '催债人' 不在词向量模型中
# 警告: 词语 '挑起者' 不在词向量模型中
# 警告: 词语 '弃民' 不在词向量模型中
# 警告: 词语 '洋大人' 不在词向量模型中
# 警告: 词语 '南青会' 不在词向量模型中
# 警告: 词语 '毒唯' 不在词向量模型中
# 警告: 词语 '女生气' 不在词向量模型中
# 警告: 词语 '平等者' 不在词向量模型中
# 警告: 词语 '理智党' 不在词向量模型中
# 警告: 词语 '精英乎' 不在词向量模型中
# 警告: 词语 '临桌' 不在词向量模型中
# 警告: 词语 '眼镜带' 不在词向量模型中
# 警告: 词语 '旁觀者' 不在词向量模型中
# 警告: 词语 '恶徒们' 不在词向量模型中
# 警告: 词语 '答主犯' 不在词向量模型中
# 警告: 词语 '阿拉伯籍' 不在词向量模型中
# 警告: 词语 '架屁' 不在词向量模型中
# 警告: 词语 '桐人' 不在词向量模型中
# 警告: 词语 '二维' 不在词向量模型中
# 警告: 词语 '选忍' 不在词向量模型中
# 警告: 词语 '捞头' 不在词向量模型中
# 警告: 词语 '稀泥老好人' 不在词向量模型中
# 警告: 词语 '屎袋子' 不在词向量模型中
# 警告: 词语 '同心會' 不在词向量模型中
# 警告: 词语 '怂怂' 不在词向量模型中
# 警告: 词语 '强权者' 不在词向量模型中
# 警告: 词语 '送人头' 不在词向量模型中
# 警告: 词语 '白罗斯' 不在词向量模型中
# 警告: 词语 '神拳' 不在词向量模型中
# 警告: 词语 '躺地' 不在词向量模型中
# 警告: 词语 '强悍者' 不在词向量模型中
# 警告: 词语 '怨种' 不在词向量模型中
# 警告: 词语 '病病' 不在词向量模型中
# 警告: 词语 '魔人' 不在词向量模型中
# 警告: 词语 '祖宗们' 不在词向量模型中
# 警告: 词语 '律师会' 不在词向量模型中
# 警告: 词语 '实战家' 不在词向量模型中
# 警告: 词语 '李文韬' 不在词向量模型中
# 警告: 词语 '奶农' 不在词向量模型中
# 警告: 词语 '童叟' 不在词向量模型中
# 警告: 词语 '谣棍' 不在词向量模型中
# 警告: 词语 '楼层主' 不在词向量模型中
# 警告: 词语 '人渣败类' 不在词向量模型中
# 警告: 词语 '舔族' 不在词向量模型中
# 警告: 词语 '一嘴毛' 不在词向量模型中
# 警告: 词语 '叛死刑' 不在词向量模型中
# 警告: 词语 '一介平民' 不在词向量模型中
# 警告: 词语 '穷生' 不在词向量模型中
# 警告: 词语 '鹏宇' 不在词向量模型中
# 警告: 词语 '染发店' 不在词向量模型中
# 警告: 词语 '姚某某' 不在词向量模型中
# 警告: 词语 '嘴毛' 不在词向量模型中
# 警告: 词语 '急急鬼' 不在词向量模型中
# 警告: 词语 '服牢役' 不在词向量模型中
# 警告: 词语 '死立执' 不在词向量模型中
# 警告: 词语 '迈克泰森' 不在词向量模型中
# 警告: 词语 '陈继治' 不在词向量模型中
# 警告: 词语 '亲哥' 不在词向量模型中
# 警告: 词语 '頩子' 不在词向量模型中
# 警告: 词语 '同伙儿' 不在词向量模型中
# 警告: 词语 '遇害人' 不在词向量模型中
# 警告: 词语 '爱丁堡人' 不在词向量模型中
# 警告: 词语 '腾片' 不在词向量模型中
# 警告: 词语 '贪婪性' 不在词向量模型中
# 警告: 词语 '交友圈' 不在词向量模型中
# 警告: 词语 '准律师' 不在词向量模型中
# 警告: 词语 '痛仇者' 不在词向量模型中
# 警告: 词语 '恶案' 不在词向量模型中
# 警告: 词语 '发心' 不在词向量模型中
# 警告: 词语 '小孩们' 不在词向量模型中
# 警告: 词语 '有前科' 不在词向量模型中
# 警告: 词语 '暴烈者' 不在词向量模型中
# 警告: 词语 '看众' 不在词向量模型中
# 警告: 词语 '水军洗地' 不在词向量模型中
# 警告: 词语 '大神们' 不在词向量模型中
# 警告: 词语 '主观者' 不在词向量模型中
# 警告: 词语 '被人' 不在词向量模型中
# 警告: 词语 '部督' 不在词向量模型中
# 警告: 词语 '陈有西' 不在词向量模型中
# 警告: 词语 '被害方' 不在词向量模型中
# 警告: 词语 '钱云会' 不在词向量模型中
# 警告: 词语 '长沙比亚' 不在词向量模型中
# 警告: 词语 '迪门口' 不在词向量模型中
# 警告: 词语 '爱国财' 不在词向量模型中
# 警告: 词语 '鸡凌弟' 不在词向量模型中
# 警告: 词语 '涉事者' 不在词向量模型中
# 警告: 词语 '非陌生人' 不在词向量模型中
# 警告: 词语 '浅见拙识' 不在词向量模型中
# 警告: 词语 '后夜跑' 不在词向量模型中
# 警告: 词语 '朱兆' 不在词向量模型中
# 警告: 词语 '锅头' 不在词向量模型中
# 警告: 词语 '挖井人' 不在词向量模型中
# 警告: 词语 '倖存者' 不在词向量模型中
# 警告: 词语 '嘴炮儿' 不在词向量模型中
# 警告: 词语 '打方' 不在词向量模型中
# 警告: 词语 '酒鬼们' 不在词向量模型中
# 警告: 词语 '刘阿斗' 不在词向量模型中
# 警告: 词语 '天水姜' 不在词向量模型中
# 警告: 词语 '那子龙' 不在词向量模型中
# 警告: 词语 '体面人' 不在词向量模型中
# 警告: 词语 '海軍' 不在词向量模型中
# 警告: 词语 '哈人' 不在词向量模型中
# 警告: 词语 '失业生' 不在词向量模型中
# 警告: 词语 '胖子壮汉' 不在词向量模型中
# 警告: 词语 '意军' 不在词向量模型中
# 警告: 词语 '恶小' 不在词向量模型中
# 警告: 词语 '犬岚' 不在词向量模型中
# 警告: 词语 '奉先' 不在词向量模型中
# 警告: 词语 '晓勇' 不在词向量模型中
# 警告: 词语 '乒兵球队' 不在词向量模型中
# 警告: 词语 '利奸' 不在词向量模型中
# 警告: 词语 '台毒' 不在词向量模型中
# 警告: 词语 '共存派' 不在词向量模型中
# 警告: 词语 '足道' 不在词向量模型中
# 警告: 词语 '甩锅星人' 不在词向量模型中
# 警告: 词语 '死咬' 不在词向量模型中
# 警告: 词语 '政法口' 不在词向量模型中
# 警告: 词语 '战略侠们' 不在词向量模型中
# 警告: 词语 '搏技师们' 不在词向量模型中
# 警告: 词语 '混蛋们' 不在词向量模型中
# 警告: 词语 '秒怂' 不在词向量模型中
# 警告: 词语 '叶大侠' 不在词向量模型中
# 警告: 词语 '金老爷子' 不在词向量模型中
# 警告: 词语 '痘印人' 不在词向量模型中
# 警告: 词语 '烧烤队' 不在词向量模型中
# 警告: 词语 '侠路' 不在词向量模型中
# 警告: 词语 '瓦来丽' 不在词向量模型中
# 警告: 词语 '格斗人' 不在词向量模型中
# 警告: 词语 '长丰人' 不在词向量模型中
# 警告: 词语 '叶问阿里泰森' 不在词向量模型中
# 警告: 词语 '肉体凡胎' 不在词向量模型中
# 警告: 词语 '恶虎' 不在词向量模型中
# 警告: 词语 '武耍赖' 不在词向量模型中
# 警告: 词语 '一身大喝' 不在词向量模型中
# 警告: 词语 '四眼仔' 不在词向量模型中
# 警告: 词语 '眼仔' 不在词向量模型中
# 警告: 词语 '黄口孺子' 不在词向量模型中
# 警告: 词语 '群攻' 不在词向量模型中
# 警告: 词语 '日本圈' 不在词向量模型中
# 警告: 词语 '人族' 不在词向量模型中
# 警告: 词语 '天神下凡' 不在词向量模型中
# 警告: 词语 '防杠精' 不在词向量模型中
# 警告: 词语 '保身派' 不在词向量模型中
# 警告: 词语 '拳修' 不在词向量模型中
# 警告: 词语 '配练' 不在词向量模型中
# 警告: 词语 '大格命' 不在词向量模型中
# 警告: 词语 '冷兵王' 不在词向量模型中
# 警告: 词语 '柯尔鸭' 不在词向量模型中
# 警告: 词语 '王格日乐' 不在词向量模型中
# 警告: 词语 '泰拳手' 不在词向量模型中
# 警告: 词语 '经验王' 不在词向量模型中
# 警告: 词语 '纯路人' 不在词向量模型中
# 警告: 词语 '猫道鼠' 不在词向量模型中
# 警告: 词语 '天选' 不在词向量模型中
# 警告: 词语 '工团' 不在词向量模型中
# 警告: 词语 '权益人' 不在词向量模型中
# 警告: 词语 '天使们' 不在词向量模型中
# 警告: 词语 '败路人缘' 不在词向量模型中
# 警告: 词语 '幼儿者' 不在词向量模型中
# 警告: 词语 '思虑周全' 不在词向量模型中
# 警告: 词语 '裁罚' 不在词向量模型中
# 警告: 词语 '丘之貉' 不在词向量模型中
# 警告: 词语 '老寡王' 不在词向量模型中
# 警告: 词语 '牛币' 不在词向量模型中
# 警告: 词语 '站队者' 不在词向量模型中
# 警告: 词语 '鸵鸟人' 不在词向量模型中
# 警告: 词语 '答主话' 不在词向量模型中
# 警告: 词语 '壞人' 不在词向量模型中
# 警告: 词语 '穿越者' 不在词向量模型中
# 警告: 词语 '白号' 不在词向量模型中
# 警告: 词语 '万疆' 不在词向量模型中
# 警告: 词语 '张云良' 不在词向量模型中
# 警告: 词语 '自干五' 不在词向量模型中
# 警告: 词语 '醉汉们' 不在词向量模型中
# 警告: 词语 '王立科' 不在词向量模型中
# 警告: 词语 '與情' 不在词向量模型中
# 警告: 词语 '发轮' 不在词向量模型中
# 警告: 词语 '毒駕' 不在词向量模型中
# 警告: 词语 '酒駕' 不在词向量模型中
# 警告: 词语 '老实本分' 不在词向量模型中
# 警告: 词语 '发字' 不在词向量模型中
# 警告: 词语 '死首恶' 不在词向量模型中
# 警告: 词语 '剑茶官' 不在词向量模型中
# 警告: 词语 '石头哥' 不在词向量模型中
# 警告: 词语 '死缓犯' 不在词向量模型中
# 警告: 词语 '哲瓦德' 不在词向量模型中
# 警告: 词语 '王菊流' 不在词向量模型中
# 警告: 词语 '胖比' 不在词向量模型中
# 警告: 词语 '徐克夏' 不在词向量模型中
# 警告: 词语 '徐灿' 不在词向量模型中
# 警告: 词语 '掷弹兵' 不在词向量模型中
# 警告: 词语 '健身人' 不在词向量模型中
# 警告: 词语 '匀称者' 不在词向量模型中
# 警告: 词语 '生死斗' 不在词向量模型中
# 警告: 词语 '圈踢' 不在词向量模型中
# 警告: 词语 '街架' 不在词向量模型中
# 警告: 词语 '里奇格林' 不在词向量模型中
# 警告: 词语 '人声版' 不在词向量模型中
# 警告: 词语 '个人渣' 不在词向量模型中
# 警告: 词语 '阿斯加德人' 不在词向量模型中
# 警告: 词语 '權威' 不在词向量模型中
# 警告: 词语 '霍格沃滋' 不在词向量模型中
# 警告: 词语 '谣言党' 不在词向量模型中
# 警告: 词语 '扫扫' 不在词向量模型中
# 警告: 词语 '常乃超' 不在词向量模型中
# 警告: 词语 '燕双鹰' 不在词向量模型中
# 警告: 词语 '纯小白' 不在词向量模型中
# 警告: 词语 '迁安人' 不在词向量模型中
# 警告: 词语 '施瓦希格' 不在词向量模型中
# 警告: 词语 '中锋位' 不在词向量模型中
# 警告: 词语 '基拉基拉' 不在词向量模型中
# 警告: 词语 '周雪光' 不在词向量模型中
# 警告: 词语 '嘎子哥' 不在词向量模型中
# 警告: 词语 '锡克族' 不在词向量模型中
# 警告: 词语 '大力鼠' 不在词向量模型中
# 警告: 词语 '罗唐' 不在词向量模型中
# 警告: 词语 '达斯汀' 不在词向量模型中
# 警告: 词语 '纯格斗外行' 不在词向量模型中
# 警告: 词语 '群嘲' 不在词向量模型中
# 警告: 词语 '肚肥' 不在词向量模型中
# 警告: 词语 '格斗黑' 不在词向量模型中
# 警告: 词语 '南阳人' 不在词向量模型中
# 警告: 词语 '脑谭儿' 不在词向量模型中
# 警告: 词语 '傻子子' 不在词向量模型中
# 警告: 词语 '滚刀狗' 不在词向量模型中
# 警告: 词语 '小被儿' 不在词向量模型中
# 警告: 词语 '新屋熊' 不在词向量模型中
# 警告: 词语 '嘴强' 不在词向量模型中
# 警告: 词语 '打野架' 不在词向量模型中
# 警告: 词语 '敏捷度' 不在词向量模型中
# 警告: 词语 '夜魔' 不在词向量模型中
# 警告: 词语 '口窝' 不在词向量模型中
# 警告: 词语 '柔道队' 不在词向量模型中
# 警告: 词语 '省三' 不在词向量模型中
# 警告: 词语 '奇迹家' 不在词向量模型中
# 警告: 词语 '菏泽人' 不在词向量模型中
# 警告: 词语 '云强者' 不在词向量模型中
# 警告: 词语 '十三军' 不在词向量模型中
# 警告: 词语 '十四军' 不在词向量模型中
# 警告: 词语 '站场子' 不在词向量模型中
# 警告: 词语 '警察会' 不在词向量模型中
# 警告: 词语 '理智者' 不在词向量模型中
# 警告: 词语 '大名警' 不在词向量模型中
# 警告: 词语 '舞蹈生' 不在词向量模型中
# 警告: 词语 '资助人' 不在词向量模型中
# 警告: 词语 '郑仁' 不在词向量模型中
# 警告: 词语 '马艳红' 不在词向量模型中
# 警告: 词语 '商言商' 不在词向量模型中
# 警告: 词语 '博后' 不在词向量模型中
# 警告: 词语 '科研人' 不在词向量模型中
# 警告: 词语 '威胁犯' 不在词向量模型中
# 警告: 词语 '净派' 不在词向量模型中
# 警告: 词语 '帖斗' 不在词向量模型中
# 警告: 词语 '唐少人' 不在词向量模型中
# 警告: 词语 '伙伙' 不在词向量模型中
# 警告: 词语 '文三爷' 不在词向量模型中
# 警告: 词语 '九敏' 不在词向量模型中
# 警告: 词语 '何丽萍' 不在词向量模型中
# 警告: 词语 '陈倩' 不在词向量模型中
# 警告: 词语 '曹德华' 不在词向量模型中
# 警告: 词语 '全族人' 不在词向量模型中
# 警告: 词语 '团长官' 不在词向量模型中
# 警告: 词语 '部下们' 不在词向量模型中
# 警告: 词语 '武举人' 不在词向量模型中
# 警告: 词语 '流产儿' 不在词向量模型中
# 警告: 词语 '美警' 不在词向量模型中
# 警告: 词语 '徐阁老' 不在词向量模型中
# 警告: 词语 '裕王' 不在词向量模型中
# 警告: 词语 '郑必昌' 不在词向量模型中
# 警告: 词语 '贪兵' 不在词向量模型中
# 警告: 词语 '全冠清' 不在词向量模型中
# 警告: 词语 '朱强' 不在词向量模型中
# 警告: 词语 '打小' 不在词向量模型中
# 警告: 词语 '立军' 不在词向量模型中
# 警告: 词语 '入殓师' 不在词向量模型中
# 警告: 词语 '执法机' 不在词向量模型中
# 警告: 词语 '干警们' 不在词向量模型中
# 警告: 词语 '套友' 不在词向量模型中
# 警告: 词语 '官儿们' 不在词向量模型中
# 警告: 词语 '贼犯' 不在词向量模型中
# 警告: 词语 '蚂蚁蛀虫' 不在词向量模型中
# 警告: 词语 '背背' 不在词向量模型中
# 警告: 词语 '施救方' 不在词向量模型中
# 警告: 词语 '兵者' 不在词向量模型中
# 警告: 词语 '对方面' 不在词向量模型中
# 警告: 词语 '不检点' 不在词向量模型中
# 警告: 词语 '差役们' 不在词向量模型中
# 警告: 词语 '权利者' 不在词向量模型中
# 警告: 词语 '洋工' 不在词向量模型中
# 警告: 词语 '省官' 不在词向量模型中
# 警告: 词语 '继签' 不在词向量模型中
# 警告: 词语 '通政达' 不在词向量模型中
# 警告: 词语 '阳山人' 不在词向量模型中
# 警告: 词语 '公警' 不在词向量模型中
# 警告: 词语 '唐小果' 不在词向量模型中
# 警告: 词语 '朱某强' 不在词向量模型中
# 警告: 词语 '警察甲' 不在词向量模型中
# 警告: 词语 '肥头党' 不在词向量模型中
# 警告: 词语 '副教导员' 不在词向量模型中
# 警告: 词语 '犯案者' 不在词向量模型中
# 警告: 词语 '拥簇们' 不在词向量模型中
# 警告: 词语 '玉器商' 不在词向量模型中
# 警告: 词语 '社招' 不在词向量模型中
# 警告: 词语 '柱子哥' 不在词向量模型中
# 警告: 词语 '韩方奕' 不在词向量模型中
# 警告: 词语 '兵号' 不在词向量模型中
# 警告: 词语 '拜登口' 不在词向量模型中
# 警告: 词语 '安东尼史密斯' 不在词向量模型中
# 警告: 词语 '典守者' 不在词向量模型中
# 警告: 词语 '动手者' 不在词向量模型中
# 警告: 词语 '小伙伴们' 不在词向量模型中
# 警告: 词语 '码畜' 不在词向量模型中
# 警告: 词语 '平顶山人' 不在词向量模型中
# 警告: 词语 '杨千幻' 不在词向量模型中
# 警告: 词语 '打架者' 不在词向量模型中
# 警告: 词语 '洪宇宙' 不在词向量模型中
# 警告: 词语 '毛班' 不在词向量模型中
# 警告: 词语 '拳王级' 不在词向量模型中
# 警告: 词语 '金腰带级' 不在词向量模型中
# 警告: 词语 '审讯者' 不在词向量模型中
# 警告: 词语 '扫黑者' 不在词向量模型中
# 警告: 词语 '查勘员' 不在词向量模型中
# 警告: 词语 '意淫棍' 不在词向量模型中
# 警告: 词语 '交流群' 不在词向量模型中
# 警告: 词语 '自己人多势众' 不在词向量模型中
# 警告: 词语 '独思者' 不在词向量模型中
# 警告: 词语 '开工者' 不在词向量模型中
# 警告: 词语 '打人团' 不在词向量模型中
# 警告: 词语 '唐和烫' 不在词向量模型中
# 警告: 词语 '侯三' 不在词向量模型中
# 警告: 词语 '特助' 不在词向量模型中
# 警告: 词语 '凌云志' 不在词向量模型中
# 警告: 词语 '马西埃' 不在词向量模型中
# 警告: 词语 '唐山格勒' 不在词向量模型中
# 警告: 词语 '陈人渣' 不在词向量模型中
# 警告: 词语 '倒霉虫' 不在词向量模型中
# 警告: 词语 '老美人' 不在词向量模型中
# 警告: 词语 '精英群' 不在词向量模型中
# 警告: 词语 '工会群' 不在词向量模型中
# 警告: 词语 '监督者们' 不在词向量模型中
# 警告: 词语 '大爷大妈' 不在词向量模型中
# 警告: 词语 '首富们' 不在词向量模型中
# 警告: 词语 '经历者' 不在词向量模型中
# 警告: 词语 '爆路人' 不在词向量模型中
# 警告: 词语 '好事之人' 不在词向量模型中
# 警告: 词语 '剑人' 不在词向量模型中
# 警告: 词语 '老王八' 不在词向量模型中
# 警告: 词语 '假信' 不在词向量模型中
# 警告: 词语 '五毛' 不在词向量模型中
# 警告: 词语 '水军们' 不在词向量模型中
# 警告: 词语 '允悲' 不在词向量模型中
# 警告: 词语 '小儿国' 不在词向量模型中
# 警告: 词语 '出院者' 不在词向量模型中
# 警告: 词语 '人上' 不在词向量模型中
# 警告: 词语 '理智派' 不在词向量模型中
# 警告: 词语 '伦敦人' 不在词向量模型中
# 警告: 词语 '分红们' 不在词向量模型中
# 警告: 词语 '入刑法' 不在词向量模型中
# 警告: 词语 '神神玩意儿' 不在词向量模型中
# 警告: 词语 '穆琴' 不在词向量模型中
# 警告: 词语 '妈生' 不在词向量模型中
# 警告: 词语 '与众' 不在词向量模型中
# 警告: 词语 '窥私' 不在词向量模型中
# 警告: 词语 '恶星' 不在词向量模型中
# 警告: 词语 '生事者' 不在词向量模型中
# 警告: 词语 '讹诈者' 不在词向量模型中
# 警告: 词语 '上边儿' 不在词向量模型中
# 警告: 词语 '迈寅' 不在词向量模型中
# 警告: 词语 '网暴社' 不在词向量模型中
# 警告: 词语 '百里侯' 不在词向量模型中
# 警告: 词语 '舌平' 不在词向量模型中
# 警告: 词语 '低能人' 不在词向量模型中
# 警告: 词语 '背楼' 不在词向量模型中
# 警告: 词语 '黑养商' 不在词向量模型中
# 警告: 词语 '利姦' 不在词向量模型中
# 警告: 词语 '黄尸' 不在词向量模型中
# 警告: 词语 '漂子' 不在词向量模型中
# 警告: 词语 '主播们' 不在词向量模型中
# 警告: 词语 '特润人' 不在词向量模型中
# 警告: 词语 '专业度' 不在词向量模型中
# 警告: 词语 '伪中客' 不在词向量模型中
# ...
# - 刘涌
# - 社死
# - 老师们
# - 肥宅
# - 陈晓亮
# - 帮助犯
# - 八竿子
# - 法考
# - 带路党
# - 鱼霸
# - 达利特
# - 打黑除恶
# - 小年轻
# - 虞关荣
# - 事业编
# - 密接
# - 大稽
# - 白衣背
# - 廊坊人
# - 北工
# - 二侄子
# - 抖机灵
# - 九漏鱼
# - 祖国人
# - 非杠
# - 逗比
# - 基本盘
# - 乐子人
# - 张麻子
# - 半佛
# - 背锅侠
# - 老板们
# - 群狼
# - 巡查组
# - 弱势者
# - 菜刀帮
# - 杨树宽
# - 高明远
# - 之士
# - 戏子们
# - 受害者们
# - 冤种
# - 二货
# - 沙人
# - 和事
# - 弱势方
# - 摇人
# - 盐贩
# - 对线
# - 拳师们
# - 普信
# - 泰州人
# - 黑社會
# - 小混子
# - 人者
# - 顶流
# - 孤勇者
# - 富人区
# - 白衣人
# - 崔伟
# - 课代表
# - 群演
# - 网曝者
# - 弱小者
# - 远某
# - 伤人者
# - 职业哥
# - 砖家
# - 张春平
# - 理中客们
# - 恶心人
# - 骚操作
# - 吴某凡
# - 发声者
# - 认怂
# - 灭霸
# - 陈礼
# - 副部
# - 谷某
# - 恰饭
# - 被害妄想症
# - 大二
# - 踏马
# - 亲者
# - 混子们
# - 大三
# - 身边人
# - 喷子们
# - 少斌
# - 理性人
# - 大四
# - 秦皇岛人
# - 株连九
# - 入刑
# - 短兵
# - 武英级
# - 狠手
# - 家属们
# - 怯者
# - 罪犯们
# - 讨论群
# - 黄淑芬
# - 官匪
# - 云拳迷
# - 韩兴博
# - 救助人
# - 霸凌者
# - 陈雷
# - 人籍
# - 鉴伤
# - 立场论者
# - 阴谋论者
# - 赖赖
# - 杀童
# - 鹰酱
# - 背刺
# - 失信人
# - 大咖
# - 小黄人
# - 关注者
# - 加害方
# - 劝离
# - 拳击界
# - 郑屠
# - 同事们
# - 王菊
# - 伟光
# - 友友们
# - 律人
# - 废青
# - 信服力
# - 喷人
# - 十三妹
# - 爱豆
# - 不负责
# - 教资
# - 小百姓
# - 污人
# - 吃瓜
# - 流官
# - 对战
# - 恶警
# - 鞋教
# - 徒弟们
# - 导员
# - 打人方
# - 工具人
# - 暴徒们
# - 带路者
# - 劳东燕
# - 见义勇
# - 政军
# - 身正
# - 渔霸
# - 小鱼小虾
# - 喽喽
# - 鸟样
# - 打黑办
# - 盲生
# - 八蛋
# - 三道杠
# - 酒疯子
# - 资本家们
# - 马某齐
# - 人神
# - 黑社会们
# - 民科
# - 讲茶
# - 他人之慨
# - 张扣扣
# - 兵王
# - 八孩
# - 欺凌者
# - 暴恐黑
# - 泱仕
# - 鲍毓明
# - 韦某木
# - 博人
# - 暴力团
# - 警人
# - 二代们
# - 米尔扎耶夫
# - 乔立夫
# - 二傻子
# - 傻缺
# - 麻瓜
# - 顾某
# - 沈奕斐
# - 脑勺
# - 玉田人
# - 警组
# - 施害方
# - 爆料人
# - 致害人
# - 造谣人
# - 恨国
# - 拳塔
# - 学生们
# - 正义侠
# - 德棍
# - 黑胖子
# - 阿米尔卡汉
# - 长兵
# - 疾控
# - 公安口
# - 巡防队
# - 葫芦僧
# - 塔西佗
# - 毁人
# - 官黑
# - 惨样
# - 高华们
# - 大棋党
# - 半残
# - 二民
# - 上位者
# - 熊心豹子
# - 屁民们
# - 专家们
# - 劝架者
# - 贝吉塔
# - 白罩衫
# - 人上人
# - 鸡贼
# - 为俊杰
# - 脑残粉
# - 人下
# - 米锅
# - 安东尼梅森
# - 高半级
# - 新闻人
# - 起色心
# - 数罪
# - 正股级
# - 精差
# - 安徽人
# - 大人们
# - 删评
# - 菜鸡
# - 崽种
# - 卑鄙者
# - 保護傘
# - 百姓们
# - 大家长
# - 助人者
# - 装逼
# - 醉酒人
# - 老大们
# - 记者们
# - 贱命
# - 人势
# - 瓮刑
# - 落水女
# - 报案者
# - 作奸犯
# - 可怜人
# - 快递员
# - 硬杠
# - 曹健华
# - 戏精
# - 学渣
# - 嫌事
# - 奥利给
# - 赵晋
# - 美芳
# - 日本兵
# - 网爆者
# - 头铁
# - 狱友们
# - 资瓷
# - 道德帝
# - 法学家们
# - 名族
# - 自媒体们
# - 杭州人
# - 治下
# - 金链子们
# - 侵犯者
# - 没钱人
# - 执言
# - 白衣郎
# - 题家
# - 穷逼
# - 老白姓
# - 暴力者
# - 接盘侠
# - 老百姓们
# - 杜特尔特
# - 副驾
# - 沈某俊
# - 节奏带
# - 犯罪史
# - 追剧
# - 商某
# - 盆友
# - 寻常人
# - 结婚率
# - 冠军们
# - 文烈宏
# - 涉黑案
# - 先烈们
# - 脏事
# - 极端主义者
# - 怂狗
# - 废宅
# - 和平者
# - 防卫者
# - 正义之士
# - 刘维国
# - 人案
# - 弈客
# - 周梅森
# - 苏北人
# - 立执
# - 混帮派
# - 前科犯
# - 邪教分子
# - 要害人
# - 茬架
# - 揭阳案
# - 唐山籍
# - 脑浆子
# - 全能神
# - 中下巴
# - 格斗吹
# - 同伙们
# - 秒人
# - 紫带
# - 手贱
# - 健将级
# - 死里
# - 胆儿
# - 猥亵犯
# - 吴天
# - 群众们
# - 省管
# - 社牛
# - 俄乌
# - 傻叉
# - 桑兰
# - 明白装
# - 三观正
# - 贱畜
# - 十户
# - 追击手
# - 陈鹤高
# - 军警界
# - 乔西里
# - 学伴
# - 苏某
# - 王馨平
# - 大佬们
# - 许凯
# - 拉架人
# - 林荷琴
# - 陈慧敏
# - 艾文礼
# - 剃刀党
# - 叼盘
# - 胖虎
# - 人事儿
# - 懵逼
# - 人拳
# - 所做所为
# - 判头
# - 精神头
# - 蒋光头
# - 黑恶分子
# - 装逼犯
# - 渎职者
# - 键盘们
# - 管方
# - 渣子们
# - 全网榜三
# - 资乎
# - 黑办
# - 渣浪
# - 歹徒们
# - 二狗子
# - 中管
# - 叠码仔
# - 逼格
# - 警会
# - 鲁智
# - 指虎
# - 张秋平
# - 张来平
# - 主角们
# - 实在人
# - 大花臂
# - 慷他人
# - 村斗
# - 喷点
# - 狼狈样
# - 豪横
# - 调戏者
# - 爆肝
# - 防守方
# - 米国人
# - 白领们
# - 官衣
# - 主犯们
# - 诬告者
# - 旭阳
# - 政治群
# - 仇杀队
# - 接触者
# - 小弟们
# - 信信
# - 北青
# - 对立方
# - 弹反
# - 军火贩
# - 苏南人
# - 诽谤性
# - 诬蔑性
# - 恶根
# - 民众们
# - 旁桌
# - 叫嚣者
# - 格斗圈
# - 快警
# - 德拉霍亚
# - 格斗吹们
# - 塞翁
# - 特巡警
# - 媒体们
# - 官员们
# - 家暴者
# - 精英们
# - 窃钩者
# - 释迦摩尼
# - 刘学周
# - 枪使
# - 疯批
# - 误导人
# - 遗少
# - 周边人
# - 炸号
# - 麻木旁观者
# - 张小果
# - 下水军
# - 逆民
# - 受伤害者
# - 脑内
# - 迈克贝
# - 王德宾
# - 人們
# - 炮王
# - 施恶者
# - 韦兆安
# - 白衣侠
# - 金心金意
# - 旁观人
# - 戚秦
# - 一份子
# - 宣传者
# - 华人们
# - 升斗
# - 企鹅人
# - 店里人
# - 二大爷
# - 扫黑组
# - 小卒子
# - 趣缘
# - 本土派
# - 麻匪
# - 饮酒人
# - 被伤者
# - 干部们
# - 高海皇
# - 施害人
# - 大斌
# - 三连
# - 马勒戈壁
# - 英雄们
# - 抓人
# - 战狼们
# - 鳄鱼帮
# - 教培
# - 惑仔
# - 不婚
# - 江苏籍
# - 人屁
# - 边缘人
# - 无关者
# - 狗屁话
# - 洗地党
# - 暴力犯
# - 参战方
# - 肖三
# - 代表们
# - 红花会
# - 衢州人
# - 检察组
# - 橘生
# - 县霸
# - 老铁们
# - 砍人案
# - 歪果仁
# - 色情业
# - 老家人
# - 傻子们
# - 倒地者
# - 进局子
# - 吃瓜群
# - 渣滓们
# - 娄娄
# - 孙启龙
# - 张春来
# - 赤鸡
# - 咖位
# - 公仆们
# - 刁民们
# - 安那其
# - 白衣胖子
# - 一帮子
# - 轮凳子
# - 近墨者
# - 正主
# - 逃刑犯
# - 爱国党
# - 草民们
# - 远程兵
# - 泰国人
# - 习武人
# - 号主
# - 巨婴们
# - 大陆人
# - 碰瓷者
# - 点边
# - 嚣张跋扈
# - 亲子班
# - 贪官们
# - 公安厅长
# - 嘿鹅
# - 张棋标
# - 张峰锋
# - 小艳
# - 张锋锋
# - 灼见
# - 警校生
# - 圈粉
# - 自嗨
# - 体问
# - 正局
# - 施虐欲
# - 强势者
# - 黄帽
# - 雅利安人
# - 威肋
# - 名道姓
# - 共情者
# - 傻屌
# - 撕逼
# - 嘴贱
# - 老哥们
# - 圣母心
# - 粉丝们
# - 以上们
# - 周树人
# - 涉恶
# - 法官们
# - 司马昭之
# - 船霸
# - 记者籍
# - 娱记
# - 鉴定师
# - 肥头
# - 药神
# - 吹哨人
# - 暑期工
# - 泰森来
# - 邪典
# - 日天
# - 酒晕子
# - 狼兵
# - 成都人
# - 包庇者
# - 犯罪份子
# - 组织人
# - 对桌
# - 陈谋志
# - 高尚者
# - 能力人
# - 键仙
# - 余欢水
# - 宋襄公
# - 社达
# - 农村人
# - 受助人
# - 流氓话
# - 牛逼症
# - 政府派
# - 小毛孩
# - 香蕉人
# - 无脑人
# - 先辈们
# - 防衛
# - 质疑者
# - 绿衣男子
# - 留言者
# - 小喽喽
# - 警擦
# - 重手
# - 怀疑主义者
# - 杀童犯
# - 姜小亮
# - 泰吹
# - 面包人
# - 牢友
# - 低人
# - 出轨者
# - 善良者
# - 杂碎们
# - 路匪
# - 装外宾
# - 罗冠军
# - 阿里周某
# - 當地人
# - 反应人
# - 大宋子民
# - 黑拳
# - 拳峰
# - 理论派
# - 陈某人
# - 赛科维奇
# - 兔友
# - 安德拉德
# - 谢帕德
# - 拉苏
# - 鲁提辖
# - 教育人
# - 小孩崽子
# - 家长们
# - 胡脸
# - 郑州人
# - 晨晟
# - 兴化人
# - 章西
# - 浩南
# - 搏击手
# - 横纲
# - 顾某杰
# - 李赛高
# - 格斗手
# - 汉谟拉比
# - 人社
# - 老乡群
# - 法助
# - 乎友
# - 无辜人
# - 董耀
# - 狗崽子们
# - 刘彦平
# - 海港区人
# - 叶某某
# - 嘴欠
# - 侵害方
# - 测试员
# - 巡特警
# - 马科长
# - 土木人
# - 答辩者
# - 侏儒人
# - 罗伊韦德
# - 柱力
# - 柱中人
# - 颜某
# - 少年头
# - 保护伞们
# - 阿中
# - 王志鹏
# - 美吹
# - 刀妹的
# - 西语系
# - 俊臣
# - 羁押期
# - 腕豪
# - 饭圈粉
# - 俩口子
# - 反黑组
# - 广东仔
# - 河南银
# - 立场主义者
# - 坏心思
# - 滋事者
# - 一行人
# - 李成阳
# - 狼叔
# - 焦彦龙
# - 张古江
# - 诸葛宇杰
# - 霉蛋
# - 米欧奇
# - 行刑者
# - 谣言者
# - 网暴人
# - 李闰
# - 苏州人
# - 阿贝阿塔
# - 农民们
# - 孙火旺
# - 山东话
# - 豆瓣人
# - 畜渣
# - 德子
# - 徐州人
# - 主从犯
# - 钢铁人
# - 车警
# - 小白鞋
# - 老炮儿
# - 小混
# - 助威者
# - 裱糊匠
# - 洪拳
# - 闰芳
# - 帖主
# - 高翻
# - 控屏
# - 袁宝璟
# - 圈苟
# - 张开印
# - 温某
# - 夏之光
# - 江浙人
# - 周秉义
# - 好官
# - 匪警
# - 洼地人
# - 赵俊
# - 高彦
# - 东北大
# - 控制欲
# - 张冠李
# - 公考编
# - 监察组
# - 侦查局
# - 拉拉案
# - 打赏
# - 出轨率
# - 模仿犯
# - 逼事
# - 右脸
# - 網民
# - 妙手医生
# - 家族人
# - 测量者
# - 起家人
# - 游侠式
# - 斧头喷子
# - 肩担道义
# - 张欲乞
# - 雨琦
# - 衰样
# - 乌合之
# - 行业者
# - 李心
# - 博白人
# - 邓公千古
# - 黑官
# - 空降派
# - 带头者
# - 暗器师
# - 法外之人
# - 格斗痴
# - 工务员
# - 不着调
# - 弱着者
# - 花人
# - 警勤
# - 对儿
# - 迷之操作
# - 唐探
# - 府台
# - 土豪分
# - 贼王
# - 爆料者
# - 面包车人
# - 脑残们
# - 建政派
# - 天杀
# - 五鼠
# - 小王八办
# - 宵小鼠辈
# - 义劲
# - 劝酒者
# - 土豪金
# - 炮头
# - 恶渣
# - 坑货
# - 张屠夫
# - 胡屠夫
# - 本地虎
# - 挽尊文
# - 护渣子
# - 网络警
# - 防卫人
# - 人建勇为
# - 医头
# - 犯案人
# - 老辈人
# - 刘捕
# - 冤死鬼
# - 继父母
# - 首恶者
# - 个名星
# - 明星圈
# - 相关方
# - 卫国者
# - 神经人
# - 造谣者们
# - 同鞋们
# - 主把
# - 动杀心
# - 萨婆阿他
# - 狍子们
# - 原画师
# - 洗白军
# - 黑心者
# - 警察长
# - 拉边上
# - 权名
# - 喷神
# - 日光族
# - 周光族
# - 护刀者
# - 猪盘
# - 收门生
# - 心花路放
# - 狗乎
# - 互助者
# - 热闹者
# - 施工者
# - 正办
# - 怪茬
# - 屋内人
# - 维京人
# - 家属长
# - 魔性笑
# - 驻警
# - 本泰迪
# - 锅蝻
# - 优势方
# - 文忙
# - 同桌人
# - 三亲六故
# - 观场
# - 反击者
# - 穷人们
# - 子弟兵们
# - 酒懵子
# - 小红帽们
# - 美媒
# - 卡萨雷斯
# - 新晋
# - 胳膊腿
# - 尔朱荣
# - 葛六
# - 葛力姆乔
# - 道上江湖
# - 踢馆人
# - 泰老虎
# - 刀法家
# - 剑术家
# - 荒天帝
# - 司乘
# - 吹子
# - 养蚕人
# - 瓜民
# - 千万富翁
# - 穷光
# - 街斗王
# - 对像
# - 队手
# - 通讯连
# - 得者
# - 鼠鼠人
# - 危墙之下
# - 大佛们
# - 庄里人
# - 主脚
# - 当局长
# - 市调人
# - 清北人
# - 富官二代
# - 无脑者
# - 润党
# - 路政支
# - 废青们
# - 按察
# - 协辅警
# - 监狱网评员
# - 律协
# - 本硕医
# - 小到达
# - 大巴掌
# - 良心粉
# - 巨佬
# - 权人
# - 洗脑包
# - 恶霸们
# - 百京人
# - 宫里人
# - 后头客
# - 审判团
# - 害群之蚂
# - 噩魔
# - 健人
# - 人在
# - 当校
# - 斥责人
# - 被组织者
# - 波热闹
# - 主体方
# - 食客们
# - 语冰
# - 消遣强
# - 暴力者们
# - 清流嘴炮
# - 陶崇园
# - 李靓蕾
# - 黑市委
# - 答者
# - 惡徒
# - 神疑鬼
# - 极端者
# - 小白们
# - 葛荣
# - 网名们
# - 流氓会
# - 传销窝
# - 满朝公卿
# - 民怒
# - 拦路匪
# - 退役者
# - 宁强县人
# - 伙拼
# - 回复者
# - 行内人
# - 顶替者
# - 相似者
# - 副县
# - 正县级
# - 孔令贻
# - 神评
# - 使枪人
# - 栽总
# - 经营人
# - 逃逸者
# - 皮渣子
# - 雅典人
# - 气生
# - 开团
# - 贵人们
# - 供养者
# - 聪明劲
# - 怀化人
# - 大青天
# - 关员
# - 信阳人
# - 大白们
# - 也纳人
# - 大哲
# - 蝇营
# - 大人者
# - 暴力分子
# - 送伤者
# - 家孩
# - 卖命钱
# - 王清远
# - 解说人
# - 金百万
# - 娱乐圈儿
# - 黑子们
# - 看戏者
# - 精人
# - 苏联人
# - 群儒
# - 傲慢者
# - 好辩者
# - 受伤害者们
# - 暴怒者
# - 进狱风
# - 牛马玩意
# - 眼镜人
# - 受众群
# - 支持者们
# - 美利坚人
# - 拉架者
# - 帮派会
# - 高手们
# - 教琴
# - 一员
# - 对派
# - 烂鬼
# - 捕快们
# - 豪杰们
# - 津唐辽
# - 黑能手
# - 屎盔子
# - 同厕
# - 华楠
# - 孟瑞鹏
# - 婉婷
# - 父老妻儿
# - 陈继某
# - 范马勇
# - 大仙儿
# - 官推
# - 张字
# - 日民
# - 好友圈
# - 实习工
# - 骚扰犯
# - 家儿
# - 储户们
# - 捧红
# - 街道人
# - 乐观主义者
# - 悲观主义者
# - 供物员
# - 叶万昌
# - 微轻伤
# - 刘志强
# - 大长腿
# - 庆嫂
# - 玩应
# - 杠精们
# - 书委
# - 韦舰长
# - 校生
# - 小丑们
# - 马恩列斯毛
# - 场裁
# - 督监
# - 散打手
# - 百族
# - 屌毛
# - 拐卖犯
# - 皖南人
# - 江西人
# - 拉黑人
# - 政圈
# - 建制派
# - 中立者
# - 砍手党
# - 回怼
# - 窃国者
# - 毕业照
# - 抖音带
# - 队友们
# - 西藏人
# - 副秘书长
# - 做恶者
# - 仁民
# - 写手们
# - 安倍桑
# - 一语
# - 金陵王
# - 贴主
# - 失道者
# - 网喷
# - 群伤
# - 大才
# - 驴人
# - 降临派
# - 不理智
# - 私力救济
# - 圣人们
# - 迫害者
# - 歧视者
# - 大胖子
# - 乘客犯
# - 洗地费
# - 脚踹
# - 理解派
# - 大法党们
# - 傻弔
# - 点赞者
# - 大张伟
# - 逃犯人
# - 区分局长
# - 网逃
# - 轮眼
# - 基本人
# - 客们
# - 弱民
# - 传谣者
# - 偏黑除恶
# - 卫道士们
# - 管家们
# - 暴力狂
# - 李钊
# - 点心员
# - 老一輩
# - 別人
# - 保镖团
# - 张鱼
# - 報警人
# - 口罩侠
# - 尾田仔
# - 大反派
# - 小地痞
# - 伤害方
# - 黑混们
# - 侠者
# - 卖锅
# - 当义人
# - 侠肝
# - 公民们
# - 开武馆
# - 体育圈
# - 大咖儿
# - 商家们
# - 大娃
# - 二娃
# - 可路人
# - 人成龙
# - 傻福
# - 土贼
# - 团工委
# - 快手大仙
# - 三下不乱
# - 人亡
# - 自私用
# - 海扁侠
# - 钞能力
# - 圈言
# - 圈语
# - 成龙大哥
# - 傻批
# - 晶哥
# - 牧民们
# - 恭俭
# - 贵己
# - 正义人
# - 宗亲会
# - 大律
# - 互联网人
# - 二人组
# - 黑白俩道
# - 迷彩服人员
# - 群伙
# - 渔老大
# - 曝光者
# - 本尊
# - 公道人
# - 黑粉头子
# - 乎儿们
# - 粉丝圈
# - 酸人
# - 张家界人
# - 小众生
# - 晋爵
# - 大伞们
# - 冀春雷
# - 乡党型
# - 完美主义者
# - 楼猪
# - 毛呵
# - 眷样
# - 被虐者
# - 烂片王
# - 仆从们
# - 效仿者
# - 张哲瀚
# - 椿椿
# - 陈烁
# - 进重症
# - 狠辣阴险
# - 肌肉块
# - 暴力份子
# - 单棍
# - 刀笔吏
# - 人秀
# - 老本地人
# - 警黑
# - 非自己人
# - 郑伯克
# - 段于鄢
# - 邢涛
# - 李树军
# - 苗德成
# - 专班
# - 咸鱼党
# - 关之檀
# - 官員
# - 教育队
# - 领导局
# - 司徒家
# - 社鼠
# - 欧心虎
# - 父母官们
# - 老友们
# - 薇娅
# - 挖墓人
# - 李丰田
# - 公权利
# - 键盘数
# - 李勇会
# - 漠叔
# - 武警队
# - 谭乔
# - 喷沙棍
# - 独苗苗
# - 陈武学
# - 法徒
# - 帮凶作用
# - 面门子
# - 长舌街溜子
# - 柔王
# - 曹志华
# - 狗屁用
# - 邻导
# - 虞某某
# - 前辈们
# - 酒客们
# - 吃瓜人
# - 中央人
# - 持刀权
# - 说话人
# - 扫地工
# - 登录人
# - 侠应
# - 人员们
# - 侦破方
# - 超市侠
# - 补充人
# - 骚年
# - 传谣者们
# - 检法院长
# - 关联人
# - 友关
# - 补门
# - 文昭
# - 惠者
# - 精明者
# - 公知权
# - 光明所
# - 马宝国
# - 市局长
# - 屁脑子
# - 徐长元
# - 非体育生
# - 黄丝
# - 洋奴们
# - 阿美利卡
# - 坚定方
# - 司法桔
# - 丑国人
# - 麻蛋
# - 晒娃
# - 三观不正
# - 自肃
# - 水军图
# - 暴民们
# - 布鲁斯李
# - 盗国者
# - 涨粉
# - 护受害者
# - 店家们
# - 店客们
# - 法奸们
# - 特权者
# - 抵抗军
# - 目击者们
# - 销售岗
# - 不见义勇为
# - 可谴责性
# - 施助者
# - 昆山龙
# - 刷差评
# - 网喷们
# - 蠢贼们
# - 小兵小将
# - 脑残货
# - 最右边
# - 使者们
# - 大神先知
# - 臭傻
# - 学者们
# - 懦弱者
# - 周围人
# - 凶面
# - 乌鸦哥
# - 好人们
# - 键盘侠群
# - 乐子党
# - 江粉
# - 灰吧
# - 纯黑道
# - 国民党徒
# - 九兽
# - 风暴眼
# - 小毛贼
# - 偷狗贼
# - 听战报
# - 装片
# - 战士们
# - 文职部
# - 表演型
# - 大喽啰
# - 地头蛇们
# - 文活
# - 马福报
# - 健盘侠
# - 宠孩
# - 孽息
# - 撒匪
# - 大黑大恶
# - 大午
# - 潘凤可
# - 敌寡友
# - 唐西哥
# - 组织会
# - 官身
# - 带师
# - 面像
# - 乡霸
# - 有害人
# - 中东人
# - 借头
# - 黑社
# - 站高点
# - 吉米仔
# - 少先
# - 老字辈
# - 行各业
# - 势力们
# - 三把手
# - 畜牲们
# - 官大爷
# - 坏人们
# - 法盲带
# - 善良人
# - 报们
# - 感情军
# - 涉黑人
# - 督战队
# - 人渣子
# - 党滴
# - 光昂辉
# - 蒙哥大汗
# - 王二奶奶
# - 公安察
# - 苏凡
# - 史王
# - 失信者
# - 管道局
# - 水军号
# - 受害面
# - 嗨涩会
# - 普车工
# - 普铣工
# - 插床工
# - 季组团
# - 贾敬龙
# - 尼马
# - 懦民
# - 企业家们
# - 某某子
# - 人畜无害
# - 居心可疑
# - 民国人
# - 大忠名臣
# - 现场者
# - 离谱者
# - 新生代们
# - 寻衅者
# - 键盘哥
# - 血偿
# - 营级
# - 群纵
# - 个匪
# - 雅库扎
# - 网宣
# - 举报侠
# - 市人
# - 程维高
# - 刘玉锟
# - 举报者们
# - 送头鸟
# - 夏想
# - 冰阔洛
# - 低官
# - 鱼小虾
# - 废掏肛狗
# - 狗们
# - 白背心
# - 浴皇大帝
# - 藤原浩
# - 侯局森
# - 巨土
# - 官员类
# - 二混子
# - 德国党
# - 猿神
# - 街娃
# - 小大哥
# - 納粹
# - 批评家们
# - 滦南县人
# - 市区人
# - 别秀
# - 坐班族
# - 年经人
# - 丫个
# - 指使者
# - 蛀虫们
# - 主嫌疑人
# - 站角
# - 唐纳德特朗普
# - 爱酱
# - 刮民党
# - 指导组
# - 心大
# - 地方人
# - 良者
# - 干饭人
# - 事儿者
# - 团伙罪
# - 人家局
# - 值班长
# - 黑恶份子
# - 芸芸众生们
# - 巡警班
# - 赵利坚
# - 接警单
# - 老毛子
# - 三儿
# - 巡防员
# - 麻爪儿
# - 从善
# - 主练长
# - 辩识力
# - 小怪
# - 淫销
# - 吊数
# - 玩命徒
# - 拳迷
# - 糊脸
# - 拳商
# - 怹萱
# - 冀八毛
# - 夜摊摊
# - 老帕们
# - 死战犯
# - 九零后
# - 公共安
# - 廊坊民不聊生
# - 少年们
# - 后台们
# - 李玟靓
# - 对答者
# - 关内人
# - 黑苏
# - 情兽
# - 黑衣黄毛
# - 民恨
# - 德意志人
# - 吃饭人
# - 雨言
# - 副领导
# - 小伙们
# - 撞墙者
# - 刀锋寨
# - 人技
# - 自述者
# - 第子们
# - 得好人
# - 袖手旁观者
# - 相助者
# - 子观音
# - 胆小者
# - 戴南镇人
# - 谭可
# - 王久宗
# - 李晓军
# - 方诚毅
# - 张郃
# - 兰室
# - 平凡者
# - 商户群
# - 肓流子
# - 贼棒
# - 民膏民脂
# - 红码案
# - 忍民
# - 簧舌
# - 贵圈
# - 房事虫
# - 春春
# - 阻碍者
# - 软茬
# - 族名
# - 保安处
# - 挨打者
# - 鬼样子
# - 王德滨
# - 被打方
# - 权益者
# - 傻货
# - 高阶级
# - 富豪们
# - 社毒
# - 流氓犯
# - 洗地者
# - 粉卫兵
# - 仇国者
# - 轻伤害
# - 有智之士
# - 人罩
# - 中医黑
# - 制定者们
# - 程继志
# - 里星爷
# - 法盲强
# - 危重症
# - 拳拳们
# - 作证人
# - 大伞云云
# - 記者
# - 作文儿
# - 陈欣然
# - 无脑喷
# - 治安者
# - 易煽动性
# - 非发言人
# - 武术家们
# - 二人黑
# - 傻波
# - 伟法
# - 牛鬼蛇神们
# - 赌路人
# - 瘦猴
# - 热血未冷
# - 內心
# - 钱劳
# - 被帮者
# - 小八嘎
# - 遭遇者
# - 黒社会
# - 公关界
# - 不法者
# - 访者
# - 人性骚扰
# - 答主们
# - 无罪者
# - 团伙人
# - 医从文
# - 受迫害者
# - 笨比
# - 帮理
# - 下棋人
# - 权师
# - 阿彌陀佛
# - 魔球迷
# - 某权们
# - 阿美利坚
# - 老牛仔们
# - 习法者
# - 受虐症
# - 付费群
# - 朋友斧正
# - 鄙視鏈
# - 處境
# - 少中之少
# - 哪根筋
# - 外面人
# - 慈老
# - 红脸男
# - 奴民
# - 清醒人
# - 猪头猪脑
# - 数字处
# - 牛啤
# - 正义欲
# - 闹谈
# - 主检法
# - 法医官
# - 八卦心
# - 理解度
# - 卤克文
# - 副所
# - 嫌疑犯们
# - 网安
# - 剑徒
# - 世家们
# - 狗腿子们
# - 人头地
# - 顾左右
# - 本侠
# - 体系人
# - 受信者
# - 冷静派
# - 顶包
# - 灰衬衫
# - 大耳
# - 明星双标
# - 管者
# - 缩头龟
# - 顺风团
# - 知命者
# - 圈仔
# - 势众
# - 混手
# - 知名人
# - 绝丁
# - 沈万
# - 键盘者
# - 狱敌
# - 現代人
# - 娛樂圈
# - 腦袋
# - 鍵盤俠
# - 醉熊
# - 墮落
# - 黑号
# - 群體
# - 美國人
# - 粉絲
# - 军记
# - 旁边人
# - 槓精
# - 炊龙哥
# - 后辈们
# - 上面人
# - 卡塔昌
# - 体校生
# - 瘦娃
# - 叽歪
# - 民兵队
# - 广西兵
# - 典韦
# - 护士美
# - 永稚
# - 南充人
# - 历史学家们
# - 正台子
# - 骨折者
# - 达华
# - 许丽娜
# - 十三燕
# - 张翠山
# - 杜易
# - 传销人
# - 狗杂碎
# - 诈骗团
# - 狠角
# - 锁嗨
# - 三口组
# - 陈级志
# - 库管
# - 人珉
# - 周震南
# - 失职者
# - 特殊科
# - 洗脑奴性
# - 获救者
# - 情杀案
# - 凶杀情杀案
# - 紙片人
# - 旧罪
# - 二啥子
# - 刑事者
# - 渣学生
# - 好事好人
# - 达瓦里氏
# - 校察
# - 拦拦
# - 逆天人
# - 哈兄
# - 战友们
# - 人方
# - 怂点
# - 醉鬼流氓
# - 暴行者
# - 上鬼
# - 混人
# - 催债人
# - 挑起者
# - 弃民
# - 洋大人
# - 南青会
# - 毒唯
# - 女生气
# - 平等者
# - 理智党
# - 精英乎
# - 临桌
# - 眼镜带
# - 旁觀者
# - 恶徒们
# - 答主犯
# - 阿拉伯籍
# - 架屁
# - 桐人
# - 二维
# - 选忍
# - 捞头
# - 稀泥老好人
# - 屎袋子
# - 同心會
# - 怂怂
# - 强权者
# - 送人头
# - 白罗斯
# - 神拳
# - 躺地
# - 强悍者
# - 怨种
# - 病病
# - 魔人
# - 祖宗们
# - 律师会
# - 实战家
# - 李文韬
# - 奶农
# - 童叟
# - 谣棍
# - 楼层主
# - 人渣败类
# - 舔族
# - 一嘴毛
# - 叛死刑
# - 一介平民
# - 穷生
# - 鹏宇
# - 染发店
# - 姚某某
# - 嘴毛
# - 急急鬼
# - 服牢役
# - 死立执
# - 迈克泰森
# - 陈继治
# - 亲哥
# - 頩子
# - 同伙儿
# - 遇害人
# - 爱丁堡人
# - 腾片
# - 贪婪性
# - 交友圈
# - 准律师
# - 痛仇者
# - 恶案
# - 发心
# - 小孩们
# - 有前科
# - 暴烈者
# - 看众
# - 水军洗地
# - 大神们
# - 主观者
# - 被人
# - 部督
# - 陈有西
# - 被害方
# - 钱云会
# - 长沙比亚
# - 迪门口
# - 爱国财
# - 鸡凌弟
# - 涉事者
# - 非陌生人
# - 浅见拙识
# - 后夜跑
# - 朱兆
# - 锅头
# - 挖井人
# - 倖存者
# - 嘴炮儿
# - 打方
# - 酒鬼们
# - 刘阿斗
# - 天水姜
# - 那子龙
# - 体面人
# - 海軍
# - 哈人
# - 失业生
# - 胖子壮汉
# - 意军
# - 恶小
# - 犬岚
# - 奉先
# - 晓勇
# - 乒兵球队
# - 利奸
# - 台毒
# - 共存派
# - 足道
# - 甩锅星人
# - 死咬
# - 政法口
# - 战略侠们
# - 搏技师们
# - 混蛋们
# - 秒怂
# - 叶大侠
# - 金老爷子
# - 痘印人
# - 烧烤队
# - 侠路
# - 瓦来丽
# - 格斗人
# - 长丰人
# - 叶问阿里泰森
# - 肉体凡胎
# - 恶虎
# - 武耍赖
# - 一身大喝
# - 四眼仔
# - 眼仔
# - 黄口孺子
# - 群攻
# - 日本圈
# - 人族
# - 天神下凡
# - 防杠精
# - 保身派
# - 拳修
# - 配练
# - 大格命
# - 冷兵王
# - 柯尔鸭
# - 王格日乐
# - 泰拳手
# - 经验王
# - 纯路人
# - 猫道鼠
# - 天选
# - 工团
# - 权益人
# - 天使们
# - 败路人缘
# - 幼儿者
# - 思虑周全
# - 裁罚
# - 丘之貉
# - 老寡王
# - 牛币
# - 站队者
# - 鸵鸟人
# - 答主话
# - 壞人
# - 穿越者
# - 白号
# - 万疆
# - 张云良
# - 自干五
# - 醉汉们
# - 王立科
# - 與情
# - 发轮
# - 毒駕
# - 酒駕
# - 老实本分
# - 发字
# - 死首恶
# - 剑茶官
# - 石头哥
# - 死缓犯
# - 哲瓦德
# - 王菊流
# - 胖比
# - 徐克夏
# - 徐灿
# - 掷弹兵
# - 健身人
# - 匀称者
# - 生死斗
# - 圈踢
# - 街架
# - 里奇格林
# - 人声版
# - 个人渣
# - 阿斯加德人
# - 權威
# - 霍格沃滋
# - 谣言党
# - 扫扫
# - 常乃超
# - 燕双鹰
# - 纯小白
# - 迁安人
# - 施瓦希格
# - 中锋位
# - 基拉基拉
# - 周雪光
# - 嘎子哥
# - 锡克族
# - 大力鼠
# - 罗唐
# - 达斯汀
# - 纯格斗外行
# - 群嘲
# - 肚肥
# - 格斗黑
# - 南阳人
# - 脑谭儿
# - 傻子子
# - 滚刀狗
# - 小被儿
# - 新屋熊
# - 嘴强
# - 打野架
# - 敏捷度
# - 夜魔
# - 口窝
# - 柔道队
# - 省三
# - 奇迹家
# - 菏泽人
# - 云强者
# - 十三军
# - 十四军
# - 站场子
# - 警察会
# - 理智者
# - 大名警
# - 舞蹈生
# - 资助人
# - 郑仁
# - 马艳红
# - 商言商
# - 博后
# - 科研人
# - 威胁犯
# - 净派
# - 帖斗
# - 唐少人
# - 伙伙
# - 文三爷
# - 九敏
# - 何丽萍
# - 陈倩
# - 曹德华
# - 全族人
# - 团长官
# - 部下们
# - 武举人
# - 流产儿
# - 美警
# - 徐阁老
# - 裕王
# - 郑必昌
# - 贪兵
# - 全冠清
# - 朱强
# - 打小
# - 立军
# - 入殓师
# - 执法机
# - 干警们
# - 套友
# - 官儿们
# - 贼犯
# - 蚂蚁蛀虫
# - 背背
# - 施救方
# - 兵者
# - 对方面
# - 不检点
# - 差役们
# - 权利者
# - 洋工
# - 省官
# - 继签
# - 通政达
# - 阳山人
# - 公警
# - 唐小果
# - 朱某强
# - 警察甲
# - 肥头党
# - 副教导员
# - 犯案者
# - 拥簇们
# - 玉器商
# - 社招
# - 柱子哥
# - 韩方奕
# - 兵号
# - 拜登口
# - 安东尼史密斯
# - 典守者
# - 动手者
# - 小伙伴们
# - 码畜
# - 平顶山人
# - 杨千幻
# - 打架者
# - 洪宇宙
# - 毛班
# - 拳王级
# - 金腰带级
# - 审讯者
# - 扫黑者
# - 查勘员
# - 意淫棍
# - 交流群
# - 自己人多势众
# - 独思者
# - 开工者
# - 打人团
# - 唐和烫
# - 侯三
# - 特助
# - 凌云志
# - 马西埃
# - 唐山格勒
# - 陈人渣
# - 倒霉虫
# - 老美人
# - 精英群
# - 工会群
# - 监督者们
# - 大爷大妈
# - 首富们
# - 经历者
# - 爆路人
# - 好事之人
# - 剑人
# - 老王八
# - 假信
# - 五毛
# - 水军们
# - 允悲
# - 小儿国
# - 出院者
# - 人上
# - 理智派
# - 伦敦人
# - 分红们
# - 入刑法
# - 神神玩意儿
# - 穆琴
# - 妈生
# - 与众
# - 窥私
# - 恶星
# - 生事者
# - 讹诈者
# - 上边儿
# - 迈寅
# - 网暴社
# - 百里侯
# - 舌平
# - 低能人
# - 背楼
# - 黑养商
# - 利姦
# - 黄尸
# - 漂子
# - 主播们
# - 特润人
# - 专业度
# - 伪中客
# - 双标党
# - 鸟克兰人
# - 正教徒
# - 评论层
# - 大刀妹
# - 实行犯
# - 西政长
# - 惩教
# - 不正三观
# - 米那桑
# - 法律君
# - 记过者
# - 洗白点
# - 社交圈内
# - 法学人
# - 法律届
# - 诺手
# - 东营人
# - 杰尼龟
# - 骂骂街
# - 提莫
# - 微博组
# - 法律生
# - 同院
# - 长相差
# - 咸鱼杠精
# - 直博
# - 熟人圈
# - 犯圈
# - 反跳忠
# - 价值观们
# - 嘴臭
# - 负责方
# - 站边
# - 抗争者
# - 段子手
# - 恐国侠
# - 警放
# - 大头兵
# - 刑事部
# - 陷思
# - 劲超
# - 约翰可汗
# - 乡巴
# - 答主杠
# - 传言人
# - 个样
# - 剧迷
# - 打家
# - 经济学人
# - 发泄者
# - 赵君旗
# - 赵微
# - 叶赫乎
# - 犯人们
# - 谣者
# - 法医界
# - 法醫
# - 粤人
# - 湛江人
# - 用心歹毒
# - 王守仁
# - 乐宗
# - 助者
# - 馋人
# - 大腰圆
# - 长辈们
# - 过前科
# - 十全恶人
# - 诸葛们
# - 撒谎人
# - 毕生所学
# - 媒妁
# - 警总
# - 正推
# - 目标者
# - 街人
# - 拳狗
# - 菩萨们
# - 宿管员
# - 傻宝
# - 小朋友们
# - 阻拦者
# - 不正经人
# - 被动方
# - 刘玉昆
# - 狂信
# - 刑拘犯
# - 全能者
# - 公孙鞅
# - 戏骨们
# - 文成武德
# - 老实巴
# - 巴交
# - 前官
# - 混夜店
# - 小金子
# - 刷外网
# - 陈续志
# - 程高维
# - 武伟东
# - 武一
# - 老焦
# - 牢工
# - 福清人
# - 大众们
# - 头子们
# - 发孝
# - 死行
# - 太史慈
# - 殴打罪
# - 宣导员们
# - 飘猴们
# - 初院
# - 配审团
# - 道委
# - 交换者
# - 张巍瀚
# - 钟杨
# - 小瘦猴
# - 啊胆
# - 小将们
# - 惰胎
# - 大成不
# - 提车帝
# - 土霸王
# - 煎蛋侠
# - 肿头
# - 乌央乌央
# - 四猫
# - 本地头蛇
# - 双标者
# - 换管员
# - 有钱型
# - 没钱型
# - 二锁
# - 外国人人
# - 男手
# - 损名
# - 观注
# - 七重
# - 冯金山
# - 李元霸
# - 拳手们
# - 尚格云顿
# - 人阿
# - 专项组
# - 鲁汛
# - 大法人
# - 艺精
# - 大清良民
# - 爆警
# - 后辈人
# - 官系
# - 评估官
# - 莫叔
# - 持刀人
# - 走丝者
# - 劫车匪
# - 竞技队
# - 圣保罗人
# - 明白人儿
# - 陈吹
# - 陈喝
# - 躺平派
# - 阿懂
# - 武盲
# - 脑仁补
# - 拜师费
# - 法学届
# - 街斗人
# - 崔飞
# - 催警
# - 李雯雯
# - 张立伟
# - 恺恩
# - 高粉丝
# - 粉粉
# - 插眼
# - 传人家
# - 黑媒
# - 放谣者
# - 专业士
# - 死条狗
# - 互殴者
# - 铁杆粉
# - 人楂
# - 劳资们
# - 西比拉
# - 拍神探
# - 劳死
# - 逼斗子
# - 刷流氓
# - 挚亲
# - 行叭
# - 新糖人
# - 同站人
# - 声筒子
# - 黑商
# - 核客
# - 谣博
# - 普盲
# - 煤老板们
# - 汤瑞景
# - 包庇犯
# - 神兔
# - 做题家
# - 道上人
# - 慕名者
# - 理客
# - 正局长
# - 上厅级
# - 副省
# - 副县区长
# - 卡塞米罗
# - 任敏
# - 陈赫高
# - 迷奸犯
# - 群分
# - 藤校
# - 陆本
# - 美本
# - 狗肉车
# - 北化工
# - 奉渝
# - 昆山人
# - 苏中人
# - 网咯
# - 旁友
# - 中单
# - 酒保们
# - 老吾老
# - 吾幼
# - 坏人堆
# - 老实派
# - 胖大哥
# - 喷格拉底
# - 志宝
# - 红小将
# - 束手旁观者
# - 宋朝人
# - 尊宝
# - 拳虱
# - 网暴狗
# - 神玩家
# - 镇中产
# - 德二
# - 老鼠人
# - 打手们
# - 卫嘴子
# - 里眼
# - 有线人
# - 尼克杨
# - 驻唱
# - 清工
# - 伸冤人
# - 天门人
# - 大旗党
# - 派人
# - 逆行者
# - 心医
# - 霖霖
# - 走狗石锤
# - 仇子龙
# - 求助人
# - 大恶人
# - 领头族
# - 瓜众
# - 当政人
# - 大奸大恶人
# - 弱孩
# - 错人
# - 内蒙人
# - 混圈
# - 六毛
# - 文科化
# - 一号
# - 跛豪
# - 仿号
# - 孟买人
# - 教训者
# - 副区
# - 实权派
# - 副国
# - 诬人
# - 我门
# - 百姓圈
# - 网上人
# - 独教才
# - 奸杀犯
# - 盆友们
# - 小屁
# - 大圣人
# - 诸葛亮亮
# - 打残
# - 凯慧
# - 烂人烂事
# - 古的白
# - 铁子们
# - 受贿方
# - 黑龙江籍
# - 电白人
# - 水东人
# - 偏架侠
# - 犯罪分身
# - 孙咸泽
# - 郭文玺
# - 水片
# - 知识分子们
# - 行动组
# - 体制人
# - 小摸
# - 事者
# - 亲身人
# - 脑路子
# - 瓜娃子
# - 某阳
# - 郭钕
# - 处置者
# - 爆脾气
# - 清国人
# - 明哲保身者
# - 對象
# - 一人之力
# - 邹西瓜
# - 差馆
# - 街溜子混子
# - 枭站粉
# - 键盘侠喷子们
# - 陪审庭
# - 重伤人
# - 王艳辉
# - 州警们
# - 李操
# - 控股人
# - 書記
# - 部平级
# - 陈学军
# - 宝坻人
# - 蔡元祺
# - 小枫红
# - 债主们
# - 曲大志
# - 张大伟
# - 韦晋
# - 纳粹主义者
# - 审美鹰
# - 笑书神侠
# - 罗大佐
# - 衣着识人
# - 贪婪心
# - 位高
# - 难防型
# - 李莫
# - 校门口流子
# - 党卫
# - 纳不粹
# - 三星圈
# - 肥头猪脑
# - 京儿爷儿
# - 耳光会
# - 健身狗
# - 邻居国
# - 白鞋队
# - 大标
# - 金帐汗
# - 科尔沁区
# - 人山
# - 顽主
# - 人等
# - 黄毛路人
# - 林宝
# - 酒友们
# - 品客
# - 守所
# - 文劝
# - 军师们
# - 阻止者
# - 职工日
# - 背调
# - 旁观们
# - 站脚
# - 指控方
# - 通行人
# - 钓鱼客
# - 陈大善人
# - 大师们
# - 泰兴人
# - 主手
# - 黑裤
# - 的仔
# - 环保人
# - 懈怠者
# - 执法口
# - 办案区
# - 同铁军
# - 执法局
# - 洗地号
# - 斗罗
# - 撰写人
# - 二逼
# - 巡回组
# - 公务员们
# - 边防员
# - 科维奇
# - 儒雅随和
# - 元霸兄
# - 唐凯
# - 人云拳迷
# - 人山口组
# - 键圣
# - 桐生一马
# - 兵器圈
# - 骗赞
# - 催债者
# - 大叔大婶
# - 格斗迷
# - 你莫属
# - 战术家
# - 兵法家
# - 斯巴达克
# - 步枪手
# - 不安分分子
# - 恶混混
# - 理智人
# - 学播
# - 主练
# - 街头群
# - 武痴
# - 帮派分子
# - 有家人
# - 传武爱好者
# - 傅欢
# - 蔡慧康
# - 曹赟定
# - 混混头
# - 于明明
# - 炒热度
# - 全删
# - 发案数
# - 逃犯数
# - 网左
# - 三学生
# - 有罪犯
# - 东莞人
# - 美国儿
# - 人性格
# - 面部长
# - 城市人
# - 刘玉玺
# - 拆白党
# - 警局长
# - 妈的
# - 洗白者
# - 杀人魔
# - 撕葱
# - 邪路子
# - 键盘鬼
# - 弟弟妹妹
# - 鸡肠贼
# - 眉鼠眼
# - 铁岭人
# - 打人者们
# - 酒徒们
# - 家伙们
# - 神经刀
# - 蚊文章
# - 明匪
# - 暗匪
# - 恶势
# - 普修生
# - 小浪花
# - 打路人
# - 杀人头
# - 典型儿
# - 剑大真
# - 张维丽
# - 吹风屁用
# - 三人组
# - 徐国庆
# - 低龄儿
# - 豪强劣绅
# - 陈平安
# - 活鳖人
# - 刘磊
# - 小年轻们
# - 远方青木
# - 彭昱畅
# - 运动员们
# - 孙国义
# - 冲锋组
# - 殴打方
# - 黑嘴
# - 刷水军
# - 呼格吉勒图案
# - 押司
# - 迅剑崽
# - 田径仔
# - 人鬼
# - 货拉拉跳车
# - 男女拳
# - 首陀罗得
# - 群愤
# - 装理客
# - 小果们
# - 人物们
# - 流氓圈
# - 六零后
# - 呆逼
# - 针织工
# - 张伟利
# - 赵紫浓
# - 妮蔻
# - 正宗大飞柱
# - 理性派
# - 帕奎奥梅威瑟
# - 永雏
# - 邢台人
# - 崔世杰
# - 武可
# - 王浩临
# - 曹黄
# - 民警们
# - 蔡永强
# - 法检司
# - 皈依者
# - 被偷者
# - 老百牲
# - 宋晓峰
# - 警察站
# - 泛民族主义者
# - 陈胜张角
# - 余伟
# - 郭全生
# - 落井下石人
# - 师医公
# - 狂霸
# - 宝友
# - 带佬
# - 厅长官
# - 名族大义
# - 恶棍们
# - 一伙子
# - 狗人
# - 惹事精
# - 乐子壬
# - 过继志
# - 英雄儿
# - 反动儿
# - 抱薪者
# - 话语者
# - 赋码爷
# - 戏二代
# - 后裔们
# - 喷战狼
# - 看官们
# - 漂亮国
# - 富球人
# - 央央
# - 鼠鼠们
# - 同僚王
# - 外检员
# - 一桌
# - 旧吏
# - 人民警
# - 王丽君
# - 大脑斧
# - 叶文杰
# - 播主
# - 演员们
# - 董宏
# - 宋老虎
# - 周国权
# - 巡控
# - 村民们
# - 喷路人
# - 戚朋好友
# - 老熟客
# - 地图头
# - 榜榜
# - 狗民
# - 粉圈控
# - 民弱
# - 清醒派
# - 网评
# - 约束人
# - 制约人
# - 资料人
# - 唐山帮
# - 呼救者
# - 贼头
# - 渣渣们
# - 人群们
# - 奴隶们
# - 绘制者
# - 恐狗
# - 西政人
# - 制造者们
# - 赵圣
# - 课班
# - 顿汉堡人
# - 球证
# - 背锅位
# - 领导位
# - 儒圈
# - 犯罪曹
# - 猎人们
# - 爆发户
# - 济宁人
# - 原住户
# - 周安
# - 武二爷
# - 兇徒
# - 民眾
# - 毒蟲
# - 催派
# - 人渣子尔
# - 大唐人
# - 绿箭侠
# - 夜巡队
# - 累累前科
# - 同流者
# - 神仙们
# - 宝宝们
# - 坐罪
# - 史文清
# - 唐普
# - 逃案犯
# - 张漂亮
# - 围观人
# - 糯康
# - 杨国权
# - 伟论
# - 朝吹
# - 躺板板
# - 警察方
# - 港警
# - 亡命钱
# - 串黑
# - 蛋糕哥
# - 暴言
# - 清官们
# - 冷暴路人
# - 鸭嗓
# - 话话
# - 双面派
# - 万族
# - 汽车长
# - 当官者
# - 公交案
# - 中華
# - 个签
# - 六普
# - 七普
# - 苏绰
# - 反诈
# - 生代
# - 平民窟
# - 言論
# - 动保
# - 鲜花社
# - 畜生们
# - 精分
# - 死鱼眼
# - 手动狗头
# - 大天
# - 父债子偿
# - 彩虹屁
# - 原子壬
# - 谷凌爱
# - 分人
# - 一把
# - 质疑声
# - 牛牛牛
# - 日媒
# - 自媒
# - 一脸
# - 财新网
# - 快银
# - 法援
# - 虎躯
# - 众筹
# - 拘留证
# - 逮捕证
# - 郭佳
# - 内心戏
# - 故意性
# - 上诉权
# - 劝架人
# - 平权主义者
#
# 任务完成，耗时: 39.04秒
